# %%
pip install streamlit
# Out:
# ...
#      ---------------------------------------- 0.0/82.0 kB ? eta -:--:--
#      ---------------------------------------- 82.0/82.0 kB 4.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/55.8 kB ? eta -:--:--
#      ---------------------------------------- 55.8/55.8 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    ---- ----------------------------------- 0.9/8.4 MB 18.3 MB/s eta 0:00:01
#    ------- -------------------------------- 1.6/8.4 MB 16.6 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.4/8.4 MB 16.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.5/8.4 MB 18.8 MB/s eta 0:00:01
#    --------------------- ------------------ 4.5/8.4 MB 19.1 MB/s eta 0:00:01
#    -------------------------- ------------- 5.6/8.4 MB 19.8 MB/s eta 0:00:01
#    ------------------------------- -------- 6.5/8.4 MB 19.7 MB/s eta 0:00:01
# ...

# %%
pip install streamlit folium streamlit_folium pandas
# Out:
# ...
#    ---------------------------------------- 0.0/325.3 kB ? eta -:--:--
#    ------- -------------------------------- 61.4/325.3 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 325.3/325.3 kB 5.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/97.0 kB ? eta -:--:--
#    ---------------------------------------- 97.0/97.0 kB ? eta 0:00:00
# ...
#   Attempting uninstall: folium
#     Found existing installation: folium 0.15.0
#     Uninstalling folium-0.15.0:
#       Successfully uninstalled folium-0.15.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install streamlit folium pandas h3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
