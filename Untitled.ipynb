# %%
pip install seaborn==0.11.2
# Out:
# ...
#      ---------------------------------------- 0.0/292.8 kB ? eta -:--:--
#      - -------------------------------------- 10.2/292.8 kB ? eta -:--:--
#      -------------- ----------------------- 112.6/292.8 kB 1.3 MB/s eta 0:00:01
#      --------------------------------- ---- 256.0/292.8 kB 2.0 MB/s eta 0:00:01
#      -------------------------------------- 292.8/292.8 kB 1.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.13.0
#     Uninstalling seaborn-0.13.0:
#       Successfully uninstalled seaborn-0.13.0
# ...
# Note: you may need to restart the kernel to use updated packages.
