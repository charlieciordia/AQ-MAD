# %% [markdown]
# ## AQ PROJECT

# %% [markdown]
# ## Visualización geolocalización

# %%
#pip install folium.plugins

# %%
#pip install geopy

# %%
import pandas as pd
import folium
import h3
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

pd.set_option('display.max_seq_items', None)

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Estaciones Ayuntamiento de Madrid

# %%
estaciones = pd.read_csv("../data/AytoMad/informacion_estaciones_red_calidad_aire.csv", sep=';')
estaciones
# Out:
#       CODIGO  CODIGO_CORTO              ESTACION  \
# 0   28079004             4       Plaza de España
# 1   28079008             8      Escuelas Aguirre
# 2   28079011            11         Ramón y Cajal
# 3   28079016            16          Arturo Soria
# 4   28079017            17            Villaverde
# 5   28079018            18             Farolillo
# 6   28079024            24         Casa de Campo
# 7   28079027            27        Barajas Pueblo
# 8   28079035            35      Plaza del Carmen
# 9   28079036            36             Moratalaz
# 10  28079038            38        Cuatro Caminos
# 11  28079039            39      Barrio del Pilar
# 12  28079040            40              Vallecas
# 13  28079047            47         Méndez Álvaro
# 14  28079048            48            Castellana
# 15  28079049            49     Parque del Retiro
# 16  28079050            50        Plaza Castilla
# 17  28079054            54  Ensanche de Vallecas
# 18  28079055            55         Urb. Embajada
# 19  28079056            56        Plaza Elíptica
# 20  28079057            57           Sanchinarro
# 21  28079058            58              El Pardo
# 22  28079059            59         Juan Carlos I
# 23  28079060            60           Tres Olivos
#
#                                             DIRECCION LONGITUD_ETRS89  \
# 0                                     Plaza de España    3°42'43.91"O
# 1                     Entre C/ Alcalá y C/ O’ Donell     3°40'56.22"O
# 2    Avda. Ramón y Cajal  esq. C/ Príncipe de Vergara    3°40'38.50"O
# 3   C/ Arturo Soria  esq. C/  Vizconde de los Asilos     3°38'21.17"O
# 4                                    C/ Juan Peñalver    3°42'47.89"O
# 5                           C/ Farolillo - C/ Ervigio    3°43'54.61"O
# 6            Casa de Campo  (Terminal del Teleférico)    3°44'50.44"O
# 7                                      C/ Júpiter, 21    3°34'48.10"O
# 8                   Plaza del Carmen esq. Tres Cruces    3°42'11.40"O
# 9       Avda. Moratalaz  esq. Camino de los Vinateros    3°38'43.02"O
# 10       Avda. Pablo Iglesias esq. C/ Marqués de Lema    3°42'25.64"O
# 11         Avda. Betanzos esq. C/  Monforte de Lemos     3°42'41.53"O
# 12        C/ Arroyo del Olivar  esq. C/  Río Grande.      3°39'5.50"O
# 13  C/ Juan de Mariana / Plaza Amanecer Méndez Álvaro    3°41'12.57"O
# 14                          C/ José Gutiérrez Abascal    3°41'25.34"O
# 15              Paseo Venezuela- Palacio de Velázquez    3º 40' 57''O
# 16                             Plaza Castilla (Canal)    3°41'19.48"O
# 17                 Avda. La Gavia / Avda. Las Suertes    3°36'43.70"O
# 18                                C/ Riaño (Barajas)     3°34'50.03"O
# 19                      Plaza Elíptica - Avda. Oporto     3°43'7.54"O
# 20           C/ Princesa de Éboli esq. C/ María Tudor    3°39'37.86"O
# 21                                   Avda. La Guardia    3°46'28.62"O
# 22  Parque Juan Carlos I (frente oficinas mantenim...     3º 36' 33"O
# 23                                 Plaza Tres Olivos     3°41'23.03"O
#
#    LATITUD_ETRS89  ALTITUD COD_TIPO        NOM_TIPO NO2  SO2   CO PM10 PM2_5  \
# 0   40°25'25.98"N      637       UT  Urbana tráfico   X    X    X  NaN   NaN
# 1   40°25'17.63"N      672       UT  Urbana tráfico   X    X    X    X     X
# 2    40°27'5.29"N      708       UT  Urbana tráfico   X  NaN  NaN  NaN   NaN
# 3   40°26'24.20"N      695       UF    Urbana fondo   X  NaN  NaN  NaN   NaN
# 4   40°20'49.74"N      601       UF    Urbana fondo   X  NaN  NaN  NaN   NaN
# 5   40°23'41.22"N      632       UF    Urbana fondo   X  NaN  NaN    X   NaN
# 6    40°25'9.69"N      646        S       Suburbana   X  NaN  NaN    X     X
# 7   40°28'36.93"N      620       UF    Urbana fondo   X  NaN  NaN  NaN   NaN
# 8    40°25'9.15"N      660       UF    Urbana fondo   X    X    X  NaN   NaN
# 9   40°24'28.64"N      671       UT  Urbana tráfico   X    X  NaN    X   NaN
# 10  40°26'43.97"N      699       UT  Urbana tráfico   X  NaN  NaN    X     X
# 11  40°28'41.64"N      676       UT  Urbana tráfico   X  NaN  NaN  NaN   NaN
# 12  40°23'17.33"N      677       UF    Urbana fondo   X  NaN  NaN    X   NaN
# 13  40°23'53.17"N      600       UF    Urbana fondo   X  NaN  NaN    X     X
# 14  40°26'23.61"N      680       UT  Urbana tráfico   X  NaN  NaN    X     X
# 15  40º 24' 52''N      662       UF    Urbana fondo   X  NaN  NaN  NaN   NaN
# 16  40°27'56.10"N      728       UT  Urbana tráfico   X  NaN  NaN    X     X
# 17  40°22'22.84"N      629       UF    Urbana fondo   X  NaN  NaN  NaN   NaN
# 18  40°27'44.51"N      619       UF    Urbana fondo   X  NaN  NaN    X   NaN
# 19   40°23'6.10"N      605       UT  Urbana tráfico   X  NaN    X    X     X
# 20  40°29'39.12"N      700       UF    Urbana fondo   X  NaN  NaN    X     X
# 21   40°31'4.97"N      612        S       Suburbana   X  NaN  NaN  NaN   NaN
# 22  40º 27' 55''N      660        S       Suburbana   X  NaN  NaN  NaN   NaN
# 23   40°30'1.97"N      715       UF    Urbana fondo   X  NaN  NaN    X   NaN
#
#      O3  BTX   COD_VIA  VIA_CLASE VIA_PAR              VIA_NOMBRE  Fecha alta  \
# 0   NaN  NaN    273600      PLAZA      DE                  ESPAÑA  01/12/1998
# 1     X    X     18900      CALLE      DE                  ALCALA  01/12/1998
# 2   NaN    X    610450      CALLE     DEL     PRINCIPE DE VERGARA  01/12/1998
# 3     X  NaN    798700      CALLE     DEL  VIZCONDE DE LOS ASILOS  01/12/1998
# 4     X  NaN    417200      CALLE      DE           JUAN PEÑALVER  01/12/1998
# 5     X    X      1903      CALLE     DEL               FAROLILLO  31/03/2001
# 6     X    X    905219  CARRETERA     DEL              TELEFERICO  01/12/1998
# 7     X  NaN    425700      CALLE      DE                 JUPITER  31/12/2002
# 8     X  NaN    145800      PLAZA     DEL                  CARMEN  01/11/1999
# 9   NaN  NaN    522000    AVENIDA      DE               MORATALAZ  01/12/1998
# 10  NaN    X    554550    AVENIDA      DE          PABLO IGLESIAS  01/11/1998
# 11    X  NaN    514425    AVENIDA      DE       MONFORTE DE LEMOS  01/05/1998
# 12  NaN  NaN     75500      CALLE     DEL       ARROYO DEL OLIVAR  30/09/1999
# 13  NaN  NaN    414800      CALLE      DE         JUAN DE MARIANA  21/12/2009
# 14  NaN  NaN    401400      CALLE      DE  JOSE GUTIERREZ ABASCAL  01/02/2010
# 15    X  NaN    905011      PASEO      DE               VENEZUELA  01/01/2010
# 16  NaN  NaN    154500      PLAZA      DE                CASTILLA  01/02/2010
# 17    X  NaN  31000516    AVENIDA      DE                LA GAVIA  11/12/2009
# 18  NaN    X    639250      CALLE      DE                   RIAÑO  20/01/2010
# 19  NaN  NaN    293200      PLAZA     NaN                ELIPTICA  18/01/2010
# 20  NaN  NaN  31000002      CALLE   DE LA       PRINCESA DE EBOLI  23/11/2009
# 21    X  NaN    348500    AVENIDA   DE LA                 GUARDIA  01/12/2009
# 22    X  NaN      1111        NaN     NaN                     NaN  14/12/2009
# 23    X  NaN      1427      PLAZA  DE LOS             TRES OLIVOS  08/02/2010
#
#    COORDENADA_X_ETRS89 COORDENADA_Y_ETRS89  LONGITUD    LATITUD
# 0          439579,3291         4475049,263 -3.712257  40.423882
# 1          442117,2366         4474770,696 -3.682316  40.421553
# 2          442564,0457         4478088,595 -3.677349  40.451473
# 3          445786,1729         4476796,019 -3.639242  40.440046
# 4          439420,7015         4466532,455 -3.713317  40.347147
# 5          437891,6961         4471832,769 -3.731836  40.394782
# 6          436598,5637         4474571,618 -3.747345  40.419358
# 7          450835,2026         4480854,172 -3.580026  40.476918
# 8          440346,3619         4474524,357 -3.703166  40.419209
# 9           445245,513         4473237,349 -3.645310  40.407952
# 10         440033,4632         4477450,211 -3.707130  40.445544
# 11         439689,0496         4481081,619 -3.711536  40.478232
# 12         444701,6871          4471043,01 -3.651529  40.388148
# 13         441715,4303         4472170,249 -3.686814  40.398099
# 14         441449,6341          4476811,42 -3.690373  40.439890
# 15           442095,52          4473981,74 -3.682500  40.414444
# 16         441609,9474         4479662,346 -3.688745  40.465584
# 17         448033,2263         4469339,044 -3.612139  40.373012
# 18         450778,8839         4479238,863 -3.580565  40.462363
# 19         438991,9161         4470741,548 -3.718768  40.385034
# 20          444026,808         4482820,581 -3.660517  40.494201
# 21            434381,6           4485548,7 -3.774610  40.518070
# 22         447744,4666         4479077,678 -3.616341  40.460726
# 23         441556,7005         4483543,994 -3.689731  40.500548

# %%
# Supongamos que tienes un DataFrame llamado 'estaciones' con las columnas 'latitud' y 'longitud'
# estaciones = pd.read_csv('archivo.csv')  # Lee tus datos desde un archivo CSV u otra fuente

# Crear un mapa centrado en una ubicación específica (por ejemplo, latitud y longitud promedio)
mapa = folium.Map(location=[estaciones['LATITUD'].mean(), estaciones['LONGITUD'].mean()], zoom_start=10)

# Agregar marcadores para cada estación
for index, row in estaciones.iterrows():
    folium.Marker([row['LATITUD'], row['LONGITUD']], popup=row['ESTACION']).add_to(mapa)

# Mostrar el mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d74dc4746de657b61aed121f81e2957 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d74dc4746de657b61aed121f81e2957&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d74dc4746de657b61aed121f81e2957 = L.map(
#                 &quot;map_2d74dc4746de657b61aed121f81e2957&quot;,
#                 {
#                     center: [40.434425633333326, -3.6793108708333335],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_170081fc5fe84f3870c383e46c1e75ad = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_170081fc5fe84f3870c383e46c1e75ad.addTo(map_2d74dc4746de657b61aed121f81e2957);
#
#
#             var marker_aac7a7308eaeaab14b6ea01051b97cfc = L.marker(
#                 [40.4238823, -3.7122567],
#                 {}
#             ).addTo(map_2d74dc4746de657b61aed121f81e2957);
#
#
#         var popup_b3d204006a20b0b6a2ab018566d97947 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5f8ca9280c6db65aceb352e3fe3a2294 = $(`&lt;div id=&quot;html_5f8ca9280c6db65aceb352e3fe3a2294&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Plaza de España&lt;/div&gt;`)[0];
#                 popup_b3d204006a20b0b6a2ab018566d97947.setContent(html_5f8ca9280c6db65aceb352e3fe3a2294);
#
#
#
#         marker_aac7a7308eaeaab14b6ea01051b97cfc.bindPopup(popup_b3d204006a20b0b6a2ab018566d97947)
#         ;
#
#
#
#
#             var marker_b35bc67b1277107cc23c2ff332db48a0 = L.marker(
#                 [40.4215533, -3.6823158],
#                 {}
#             ).addTo(map_2d74dc4746de657b61aed121f81e2957);
#
#
#         var popup_0aaf570c58a8aa7141b3efa2ed1e40da = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_da36e304ee2338580bcd81f2b216a234 = $(`&lt;div id=&quot;html_da36e304ee2338580bcd81f2b216a234&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Escuelas Aguirre&lt;/div&gt;`)[0];
#                 popup_0aaf570c58a8aa7141b3efa2ed1e40da.setContent(html_da36e304ee2338580bcd81f2b216a234);
#
#
#
#         marker_b35bc67b1277107cc23c2ff332db48a0.bindPopup(popup_0aaf570c58a8aa7141b3efa2ed1e40da)
#         ;
#
#
#
#
#             var marker_21d299682ee86defde82e409e7797fc7 = L.marker(
#                 [40.4514734, -3.6773491],
#                 {}
#             ).addTo(map_2d74dc4746de657b61aed121f81e2957);
#
#
#         var popup_7d0f450b98084e31b07d28034d7c3643 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0eae013ac302e8b2df12381e3b3987ce = $(`&lt;div id=&quot;html_0eae013ac302e8b2df12381e3b3987ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ramón y Cajal&lt;/div&gt;`)[0];
#                 popup_7d0f450b98084e31b07d28034d7c3643.setContent(html_0eae013ac302e8b2df12381e3b3987ce);
#
#
#
#         marker_21d299682ee86defde82e409e7797fc7.bindPopup(popup_7d0f450b98084e31b07d28034d7c3643)
#         ;
#
#
#
#
#             var marker_fd7c07cae664a04dfddcab5e73520ebd = L.marker(
#                 [40.4400457, -3.6392422],
#                 {}
#             ).addTo(map_2d74dc4746de657b61aed121f81e2957);
#
#
#         var popup_04635c565b9a97c8c818f1bb90b5d197 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_29f5bee7dae905ecaf060b319ecb267c = $(`&lt;div id=&quot;html_29f5bee7dae905ecaf060b319ecb267c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arturo Soria&lt;/div&gt;`)[0];
#                 popup_04635c565b9a97c8c818f1bb90b5d197.setContent(html_29f5bee7dae905ecaf060b319ecb267c);
#
#
#
#         marker_fd7c07cae664a04dfddcab5e73520ebd.bindPopup(popup_04635c565b9a97c8c818f1bb90b5d197)
#         ;
#
#
#
#
#             var marker_8baa7b7cf16119692f409b43c4d3a548 = L.marker(
#                 [40.347147, -3.7133167],
#                 {}
#             ).addTo(map_2d74dc4746de657b61aed121f81e2957);
#
#
#         var popup_a419376fb8325d775b7689ed7c4ad87b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_417c9ac05052f579f6f0e3ea9c64a8aa = $(`&lt;div id=&quot;html_417c9ac05052f579f6f0e3ea9c64a8aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Villaverde&lt;/div&gt;`)[0];
#                 popup_a419376fb8325d775b7689ed7c4ad87b.setContent(html_417c9ac05052f579f6f0e3ea9c64a8aa);
#
#
#
#         marker_8baa7b7cf16119692f409b43c4d3a548.bindPopup(popup_a419376fb8325d775b7689ed7c4ad87b)
#         ;
#
#
#
#
#             var marker_b96bde131945d402cdba99737626c042 = L.marker(
#                 [40.3947825, -3.7318356],
#                 {}
#             ).addTo(map_2d74dc4746

# %%
# Renombrar las columnas CODIGO_CORTO y ESTACION
nuevos_nombres = {'CODIGO_CORTO': 'ESTACION', 'ESTACION': 'NOMBRE'}
estaciones = estaciones.rename(columns=nuevos_nombres)

# %%
estaciones.head()
# Out:
#      CODIGO  ESTACION            NOMBRE  \
# 0  28079004         4   Plaza de España
# 1  28079008         8  Escuelas Aguirre
# 2  28079011        11     Ramón y Cajal
# 3  28079016        16      Arturo Soria
# 4  28079017        17        Villaverde
#
#                                            DIRECCION LONGITUD_ETRS89  \
# 0                                    Plaza de España    3°42'43.91"O
# 1                    Entre C/ Alcalá y C/ O’ Donell     3°40'56.22"O
# 2   Avda. Ramón y Cajal  esq. C/ Príncipe de Vergara    3°40'38.50"O
# 3  C/ Arturo Soria  esq. C/  Vizconde de los Asilos     3°38'21.17"O
# 4                                   C/ Juan Peñalver    3°42'47.89"O
#
#   LATITUD_ETRS89  ALTITUD COD_TIPO        NOM_TIPO NO2  SO2   CO PM10 PM2_5  \
# 0  40°25'25.98"N      637       UT  Urbana tráfico   X    X    X  NaN   NaN
# 1  40°25'17.63"N      672       UT  Urbana tráfico   X    X    X    X     X
# 2   40°27'5.29"N      708       UT  Urbana tráfico   X  NaN  NaN  NaN   NaN
# 3  40°26'24.20"N      695       UF    Urbana fondo   X  NaN  NaN  NaN   NaN
# 4  40°20'49.74"N      601       UF    Urbana fondo   X  NaN  NaN  NaN   NaN
#
#     O3  BTX  COD_VIA VIA_CLASE VIA_PAR              VIA_NOMBRE  Fecha alta  \
# 0  NaN  NaN   273600     PLAZA      DE                  ESPAÑA  01/12/1998
# 1    X    X    18900     CALLE      DE                  ALCALA  01/12/1998
# 2  NaN    X   610450     CALLE     DEL     PRINCIPE DE VERGARA  01/12/1998
# 3    X  NaN   798700     CALLE     DEL  VIZCONDE DE LOS ASILOS  01/12/1998
# 4    X  NaN   417200     CALLE      DE           JUAN PEÑALVER  01/12/1998
#
#   COORDENADA_X_ETRS89 COORDENADA_Y_ETRS89  LONGITUD    LATITUD
# 0         439579,3291         4475049,263 -3.712257  40.423882
# 1         442117,2366         4474770,696 -3.682316  40.421553
# 2         442564,0457         4478088,595 -3.677349  40.451473
# 3         445786,1729         4476796,019 -3.639242  40.440046
# 4         439420,7015         4466532,455 -3.713317  40.347147

# %% [markdown]
# ### Calidad del aire - NO2

# %% [markdown]
# *NO2 es la magnitud 8*

# %%
df = pd.read_csv("../data/AytoMad/Anio23/abr_mo23.csv", sep=';')
df.head()
# Out:
#    PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  DIA  \
# 0         28         79         4         1  28079004_1_38  2023    4    1
# 1         28         79         4         1  28079004_1_38  2023    4    2
# 2         28         79         4         1  28079004_1_38  2023    4    3
# 3         28         79         4         1  28079004_1_38  2023    4    4
# 4         28         79         4         1  28079004_1_38  2023    4    5
#
#    H01 V01  H02 V02  H03 V03  H04 V04  H05 V05  H06 V06  H07 V07  H08 V08  \
# 0  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V
# 1  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V
# 2  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V
# 3  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  2.0   V
# 4  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  2.0   V
#
#    H09 V09  H10 V10  H11 V11  H12 V12    H13 V13  H14 V14  H15 V15  H16 V16  \
# 0  1.0   V  1.0   V  1.0   V  1.0   V    1.0   V  1.0   V  1.0   V  1.0   V
# 1  1.0   V  1.0   V  1.0   V  1.0   V    1.0   V  1.0   V  1.0   V  1.0   V
# 2  2.0   V  2.0   V  2.0   V  1.0   V    1.0   V  1.0   V  1.0   V  1.0   V
# 3  2.0   V  2.0   V  1.0   V  1.0   V    1.0   V  1.0   V  1.0   V  1.0   V
# 4  3.0   V  2.0   N  1.0   N  3.0   N  127.0   N  1.0   V  1.0   V  1.0   V
#
#    H17 V17  H18 V18  H19 V19  H20 V20  H21 V21  H22 V22  H23 V23  H24 V24
# 0  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V
# 1  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V
# 2  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V
# 3  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V
# 4  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V

# %%
dfNO2 = df[df["MAGNITUD"] == 8]

# %%
dfNO2.head()
# Out:
#     PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  DIA  \
# 90         28         79         4         8   28079004_8_8  2023    4    1
# 91         28         79         4         8   28079004_8_8  2023    4    2
# 92         28         79         4         8   28079004_8_8  2023    4    3
# 93         28         79         4         8   28079004_8_8  2023    4    4
# 94         28         79         4         8   28079004_8_8  2023    4    5
#
#      H01 V01   H02 V02   H03 V03   H04 V04   H05 V05   H06 V06   H07 V07  \
# 90  10.0   V  14.0   V   9.0   V   7.0   V   3.0   V   2.0   V   4.0   V
# 91  12.0   V  16.0   V  21.0   V  15.0   V   7.0   V   6.0   V  10.0   V
# 92  11.0   V  11.0   V   9.0   V   6.0   V   5.0   V  13.0   V  28.0   V
# 93  16.0   V  38.0   V  33.0   V  22.0   V  18.0   V  21.0   V  17.0   V
# 94  14.0   V  18.0   V  13.0   V  12.0   V  10.0   V  18.0   V  33.0   V
#
#      H08 V08   H09 V09   H10 V10    H11 V11    H12 V12   H13 V13   H14 V14  \
# 90   6.0   V  14.0   V  15.0   V   11.0   V   10.0   V   7.0   V   7.0   V
# 91  20.0   V  30.0   V  27.0   V   17.0   V   10.0   V   7.0   V   5.0   V
# 92  52.0   V  57.0   V  44.0   V   44.0   V   36.0   V  33.0   V  27.0   V
# 93  67.0   V  50.0   V  32.0   V   24.0   V   20.0   V  14.0   V  10.0   V
# 94  53.0   V  65.0   V  26.0   N  115.0   N  132.0   N  23.0   N  15.0   V
#
#      H15 V15   H16 V16   H17 V17   H18 V18   H19 V19   H20 V20   H21 V21  \
# 90   5.0   V   4.0   V   3.0   V   7.0   V   8.0   V   6.0   V  10.0   V
# 91   6.0   V   5.0   V   5.0   V   5.0   V   8.0   V  11.0   V  12.0   V
# 92  26.0   V  21.0   V  21.0   V  11.0   V  10.0   V  13.0   V  26.0   V
# 93   7.0   V   7.0   V   8.0   V   8.0   V   9.0   V   9.0   V  13.0   V
# 94  15.0   V  14.0   V  11.0   V  14.0   V  17.0   V  22.0   V  32.0   V
#
#      H22 V22   H23 V23   H24 V24
# 90  13.0   V  11.0   V  16.0   V
# 91  17.0   V  19.0   V  20.0   V
# 92  30.0   V  26.0   V  23.0   V
# 93  15.0   V  18.0   V  15.0   V
# 94  76.0   V  94.0   V  85.0   V

# %%
dfNO2.shape
# Out:
# (720, 56)

# %%
columnas_a_eliminar = [f"V{i:02d}" for i in range(1, 25)]
dfNO2_clean = dfNO2.drop(columnas_a_eliminar, axis=1)

# %%
dfNO2_clean.head()
# Out:
#     PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  DIA  \
# 90         28         79         4         8   28079004_8_8  2023    4    1
# 91         28         79         4         8   28079004_8_8  2023    4    2
# 92         28         79         4         8   28079004_8_8  2023    4    3
# 93         28         79         4         8   28079004_8_8  2023    4    4
# 94         28         79         4         8   28079004_8_8  2023    4    5
#
#      H01   H02   H03   H04   H05   H06   H07   H08   H09   H10    H11    H12  \
# 90  10.0  14.0   9.0   7.0   3.0   2.0   4.0   6.0  14.0  15.0   11.0   10.0
# 91  12.0  16.0  21.0  15.0   7.0   6.0  10.0  20.0  30.0  27.0   17.0   10.0
# 92  11.0  11.0   9.0   6.0   5.0  13.0  28.0  52.0  57.0  44.0   44.0   36.0
# 93  16.0  38.0  33.0  22.0  18.0  21.0  17.0  67.0  50.0  32.0   24.0   20.0
# 94  14.0  18.0  13.0  12.0  10.0  18.0  33.0  53.0  65.0  26.0  115.0  132.0
#
#      H13   H14   H15   H16   H17   H18   H19   H20   H21   H22   H23   H24
# 90   7.0   7.0   5.0   4.0   3.0   7.0   8.0   6.0  10.0  13.0  11.0  16.0
# 91   7.0   5.0   6.0   5.0   5.0   5.0   8.0  11.0  12.0  17.0  19.0  20.0
# 92  33.0  27.0  26.0  21.0  21.0  11.0  10.0  13.0  26.0  30.0  26.0  23.0
# 93  14.0  10.0   7.0   7.0   8.0   8.0   9.0   9.0  13.0  15.0  18.0  15.0
# 94  23.0  15.0  15.0  14.0  11.0  14.0  17.0  22.0  32.0  76.0  94.0  85.0

# %%
# Lista de columnas de horas
columnas_horas = [f'H{i:02d}' for i in range(1, 25)]

# Calcular la media de las columnas H01 a H24
dfNO2_clean['avg'] = dfNO2_clean[columnas_horas].mean(axis=1)

# %%
dfNO2_clean.head()
# Out:
#     PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  DIA  \
# 90         28         79         4         8   28079004_8_8  2023    4    1
# 91         28         79         4         8   28079004_8_8  2023    4    2
# 92         28         79         4         8   28079004_8_8  2023    4    3
# 93         28         79         4         8   28079004_8_8  2023    4    4
# 94         28         79         4         8   28079004_8_8  2023    4    5
#
#      H01   H02   H03   H04   H05   H06   H07   H08   H09   H10    H11    H12  \
# 90  10.0  14.0   9.0   7.0   3.0   2.0   4.0   6.0  14.0  15.0   11.0   10.0
# 91  12.0  16.0  21.0  15.0   7.0   6.0  10.0  20.0  30.0  27.0   17.0   10.0
# 92  11.0  11.0   9.0   6.0   5.0  13.0  28.0  52.0  57.0  44.0   44.0   36.0
# 93  16.0  38.0  33.0  22.0  18.0  21.0  17.0  67.0  50.0  32.0   24.0   20.0
# 94  14.0  18.0  13.0  12.0  10.0  18.0  33.0  53.0  65.0  26.0  115.0  132.0
#
#      H13   H14   H15   H16   H17   H18   H19   H20   H21   H22   H23   H24  \
# 90   7.0   7.0   5.0   4.0   3.0   7.0   8.0   6.0  10.0  13.0  11.0  16.0
# 91   7.0   5.0   6.0   5.0   5.0   5.0   8.0  11.0  12.0  17.0  19.0  20.0
# 92  33.0  27.0  26.0  21.0  21.0  11.0  10.0  13.0  26.0  30.0  26.0  23.0
# 93  14.0  10.0   7.0   7.0   8.0   8.0   9.0   9.0  13.0  15.0  18.0  15.0
# 94  23.0  15.0  15.0  14.0  11.0  14.0  17.0  22.0  32.0  76.0  94.0  85.0
#
#           avg
# 90   8.416667
# 91  12.958333
# 92  24.291667
# 93  20.458333
# 94  38.625000

# %%
cols = ["PROVINCIA", "MUNICIPIO", "MAGNITUD", "PUNTO_MUESTREO", "ANO", "MES", "DIA", "H01","H02","H03","H04","H05","H06","H07","H08","H09","H10","H11","H12","H13","H14","H15","H16","H17","H18","H19","H20","H21","H22","H23","H24" ]

# %%
prueba = dfNO2_clean.drop(cols, axis=1)

# %%
prueba2 = prueba.groupby("ESTACION").mean()
prueba2.head()
# Out:
#                 avg
# ESTACION
# 4         23.915278
# 8         27.686111
# 11        24.776389
# 16        21.526389
# 17        30.927778

# %%
prueba_map= pd.merge(prueba2, estaciones[['ESTACION', 'LATITUD', 'LONGITUD']], on='ESTACION', how='left')
prueba_map.head()
# Out:
#    ESTACION        avg    LATITUD  LONGITUD
# 0         4  23.915278  40.423882 -3.712257
# 1         8  27.686111  40.421553 -3.682316
# 2        11  24.776389  40.451473 -3.677349
# 3        16  21.526389  40.440046 -3.639242
# 4        17  30.927778  40.347147 -3.713317

# %%
prueba_map.rename(columns={'Avg': 'NO2 avg'}, inplace=True)

# %%
prueba_map.to_csv('../clean_visuals/hextaciones.csv', index=False)

# %%
prueba_map
# Out:
#     Estacion        Avg    Latitud  Longitud               h3
# 0          4  23.915278  40.423882 -3.712257  87390cb1bffffff
# 1          8  27.686111  40.421553 -3.682316  87390ca26ffffff
# 2         11  24.776389  40.451473 -3.677349  87390ca24ffffff
# 3         16  21.526389  40.440046 -3.639242  87390ca25ffffff
# 4         17  30.927778  40.347147 -3.713317  87390cb89ffffff
# 5         18  20.720833  40.394782 -3.731836  87390cba9ffffff
# 6         24  12.198611  40.419358 -3.747345  87390cbadffffff
# 7         27  28.345833  40.476918 -3.580026  87390cb51ffffff
# 8         35  37.269444  40.419209 -3.703166  87390cb1bffffff
# 9         36  22.609722  40.407952 -3.645310  87390ca22ffffff
# 10        38  20.637500  40.445544 -3.707130  87390cb19ffffff
# 11        39  22.623611  40.478232 -3.711536  87390cb0effffff
# 12        40  23.975000  40.388148 -3.651529  87390ca31ffffff
# 13        47  24.875000  40.398099 -3.686814  87390ca35ffffff
# 14        48  22.952778  40.439890 -3.690373  87390cb19ffffff
# 15        49  15.341667  40.414444 -3.682500  87390ca35ffffff
# 16        50  24.806944  40.465584 -3.688745  87390cb0affffff
# 17        54  25.709722  40.373012 -3.612139  87390ca00ffffff
# 18        55  25.019444  40.462363 -3.580565  87390cb53ffffff
# 19        56  29.716667  40.385034 -3.718768  87390ca36ffffff
# 20        57  17.955556  40.494201 -3.660517  87390cb09ffffff
# 21        58   9.844444  40.518070 -3.774610  87390cb04ffffff
# 22        59  18.083333  40.460726 -3.616341  87390cb52ffffff
# 23        60  15.201389  40.500548 -3.689731  87390cb0cffffff
# 24        90  22.689352  40.463120 -3.702471  87390cb1dffffff
# 25        91  22.501852  40.436439 -3.703253  87390cb19ffffff
# 26        92  21.795370  40.479339 -3.686933  87390cb08ffffff
# 27        93  20.271759  40.468800 -3.651402  87390cb0bffffff
# 28        94  18.056944  40.421620 -3.729801  87390cb1affffff
# 29        95  22.797917  40.396441 -3.709325  87390ca34ffffff
# 30        96  26.845833  40.386591 -3.685148  87390ca30ffffff
# 31        97  16.418056  40.432451 -3.727237  87390cb18ffffff

# %% [markdown]
# ## Interpolación para generar nuevos registros

# %% [markdown]
# #### 3 puntos

# %%
# Obtener los valores de las estaciones 38, 39 y 40
valores_estaciones = prueba_map[prueba_map['ESTACION'].isin([38, 39, 50])]['avg']

# Calcular la media de los valores de las estaciones 38, 39 y 50
nuevo_valor_avg = valores_estaciones.mean()

# Calcular la media de las coordenadas para obtener el nuevo punto
nueva_latitud = prueba_map[prueba_map['ESTACION'].isin([38, 39, 50])]['LATITUD'].mean()
nueva_longitud = prueba_map[prueba_map['ESTACION'].isin([38, 39, 50])]['LONGITUD'].mean()

# Crear el nuevo registro
nuevo_registro = {
    'ESTACION': 90,
    'avg': nuevo_valor_avg,
    'LATITUD': nueva_latitud,
    'LONGITUD': nueva_longitud
}

# Crear un DataFrame con el nuevo registro
nuevo_registro_df = pd.DataFrame([nuevo_registro])

# Agregar el nuevo registro al DataFrame original
prueba_map = pd.concat([prueba_map, nuevo_registro_df], ignore_index=True)

# %%
# Obtener los valores de las estaciones 38, 48, 4
valores_estaciones = prueba_map[prueba_map['ESTACION'].isin([38, 48, 4])]['avg']

# Calcular la media de los valores de las estaciones 38, 48, 4
nuevo_valor_avg = valores_estaciones.mean()

# Calcular la media de las coordenadas para obtener el nuevo punto
nueva_latitud = prueba_map[prueba_map['ESTACION'].isin([38, 48, 4])]['LATITUD'].mean()
nueva_longitud = prueba_map[prueba_map['ESTACION'].isin([38, 48, 4])]['LONGITUD'].mean()

# Crear el nuevo registro
nuevo_registro = {
    'ESTACION': 91,
    'avg': nuevo_valor_avg,
    'LATITUD': nueva_latitud,
    'LONGITUD': nueva_longitud
}

# Crear un DataFrame con el nuevo registro
nuevo_registro_df = pd.DataFrame([nuevo_registro])

# Agregar el nuevo registro al DataFrame original
prueba_map = pd.concat([prueba_map, nuevo_registro_df], ignore_index=True)

# %%
# Obtener los valores de las estaciones 39, 50, 57
valores_estaciones = prueba_map[prueba_map['ESTACION'].isin([39, 50, 57])]['avg']

# Calcular la media de los valores de las estaciones 39, 50, 57
nuevo_valor_avg = valores_estaciones.mean()

# Calcular la media de las coordenadas para obtener el nuevo punto
nueva_latitud = prueba_map[prueba_map['ESTACION'].isin([39, 50, 57])]['LATITUD'].mean()
nueva_longitud = prueba_map[prueba_map['ESTACION'].isin([39, 50, 57])]['LONGITUD'].mean()

# Crear el nuevo registro
nuevo_registro = {
    'ESTACION': 92,
    'avg': nuevo_valor_avg,
    'LATITUD': nueva_latitud,
    'LONGITUD': nueva_longitud
}

# Crear un DataFrame con el nuevo registro
nuevo_registro_df = pd.DataFrame([nuevo_registro])

# Agregar el nuevo registro al DataFrame original
prueba_map = pd.concat([prueba_map, nuevo_registro_df], ignore_index=True)

# %%
# Obtener los valores de las estaciones 57, 11, 59
valores_estaciones = prueba_map[prueba_map['ESTACION'].isin([57, 11, 59])]['avg']

# Calcular la media de los valores de las estaciones 57, 11, 59
nuevo_valor_avg = valores_estaciones.mean()

# Calcular la media de las coordenadas para obtener el nuevo punto
nueva_latitud = prueba_map[prueba_map['ESTACION'].isin([57, 11, 59])]['LATITUD'].mean()
nueva_longitud = prueba_map[prueba_map['ESTACION'].isin([57, 11, 59])]['LONGITUD'].mean()

# Crear el nuevo registro
nuevo_registro = {
    'ESTACION': 93,
    'avg': nuevo_valor_avg,
    'LATITUD': nueva_latitud,
    'LONGITUD': nueva_longitud
}

# Crear un DataFrame con el nuevo registro
nuevo_registro_df = pd.DataFrame([nuevo_registro])

# Agregar el nuevo registro al DataFrame original
prueba_map = pd.concat([prueba_map, nuevo_registro_df], ignore_index=True)

# %% [markdown]
# #### 2 puntos

# %%
# Obtener los valores de las estaciones 4, 24
valores_estaciones = prueba_map[prueba_map['ESTACION'].isin([4, 24])]['avg']

# Calcular la media de los valores de las estaciones 4, 24
nuevo_valor_avg = valores_estaciones.mean()

# Calcular la media de las coordenadas para obtener el nuevo punto
nueva_latitud = prueba_map[prueba_map['ESTACION'].isin([4, 24])]['LATITUD'].mean()
nueva_longitud = prueba_map[prueba_map['ESTACION'].isin([4, 24])]['LONGITUD'].mean()

# Crear el nuevo registro
nuevo_registro = {
    'ESTACION': 94,
    'avg': nuevo_valor_avg,
    'LATITUD': nueva_latitud,
    'LONGITUD': nueva_longitud
}

# Crear un DataFrame con el nuevo registro
nuevo_registro_df = pd.DataFrame([nuevo_registro])

# Agregar el nuevo registro al DataFrame original
prueba_map = pd.concat([prueba_map, nuevo_registro_df], ignore_index=True)

# %%
# Obtener los valores de las estaciones 18, 47
valores_estaciones = prueba_map[prueba_map['ESTACION'].isin([18, 47])]['avg']

# Calcular la media de los valores de las estaciones18, 47
nuevo_valor_avg = valores_estaciones.mean()

# Calcular la media de las coordenadas para obtener el nuevo punto
nueva_latitud = prueba_map[prueba_map['ESTACION'].isin([18, 47])]['LATITUD'].mean()
nueva_longitud = prueba_map[prueba_map['ESTACION'].isin([18, 47])]['LONGITUD'].mean()

# Crear el nuevo registro
nuevo_registro = {
    'ESTACION': 95,
    'avg': nuevo_valor_avg,
    'LATITUD': nueva_latitud,
    'LONGITUD': nueva_longitud
}

# Crear un DataFrame con el nuevo registro
nuevo_registro_df = pd.DataFrame([nuevo_registro])

# Agregar el nuevo registro al DataFrame original
prueba_map = pd.concat([prueba_map, nuevo_registro_df], ignore_index=True)

# %%
# Obtener los valores de las estaciones 40, 56
valores_estaciones = prueba_map[prueba_map['ESTACION'].isin([40, 56])]['avg']

# Calcular la media de los valores de las estaciones 40, 56
nuevo_valor_avg = valores_estaciones.mean()

# Calcular la media de las coordenadas para obtener el nuevo punto
nueva_latitud = prueba_map[prueba_map['ESTACION'].isin([40, 56])]['LATITUD'].mean()
nueva_longitud = prueba_map[prueba_map['ESTACION'].isin([40, 56])]['LONGITUD'].mean()

# Crear el nuevo registro
nuevo_registro = {
    'ESTACION': 96,
    'avg': nuevo_valor_avg,
    'LATITUD': nueva_latitud,
    'LONGITUD': nueva_longitud
}

# Crear un DataFrame con el nuevo registro
nuevo_registro_df = pd.DataFrame([nuevo_registro])

# Agregar el nuevo registro al DataFrame original
prueba_map = pd.concat([prueba_map, nuevo_registro_df], ignore_index=True)

# %%
# Obtener los valores de las estaciones 24, 38
valores_estaciones = prueba_map[prueba_map['ESTACION'].isin([24, 38])]['avg']

# Calcular la media de los valores de las estaciones 24, 38
nuevo_valor_avg = valores_estaciones.mean()

# Calcular la media de las coordenadas para obtener el nuevo punto
nueva_latitud = prueba_map[prueba_map['ESTACION'].isin([24, 38])]['LATITUD'].mean()
nueva_longitud = prueba_map[prueba_map['ESTACION'].isin([24, 38])]['LONGITUD'].mean()

# Crear el nuevo registro
nuevo_registro = {
    'ESTACION': 97,
    'avg': nuevo_valor_avg,
    'LATITUD': nueva_latitud,
    'LONGITUD': nueva_longitud
}

# Crear un DataFrame con el nuevo registro
nuevo_registro_df = pd.DataFrame([nuevo_registro])

# Agregar el nuevo registro al DataFrame original
prueba_map = pd.concat([prueba_map, nuevo_registro_df], ignore_index=True)

# %%
prueba_map.columns = [col.capitalize() for col in prueba_map.columns]

# %%
prueba_map.head()
# Out:
#    Estacion        Avg    Latitud  Longitud
# 0         4  23.915278  40.423882 -3.712257
# 1         8  27.686111  40.421553 -3.682316
# 2        11  24.776389  40.451473 -3.677349
# 3        16  21.526389  40.440046 -3.639242
# 4        17  30.927778  40.347147 -3.713317

# %% [markdown]
# ## H3 👀

# %%
RES = 7

# %%
prueba_map['h3'] = prueba_map.apply(lambda x: h3.geo_to_h3(x.Latitud, x.Longitud, RES), axis =1)

# %%
import pydeck as pdk

# %%
layer = pdk.Layer("H3HexagonLayer", prueba_map, pickable=True, stroked=True, filled=True, extruded=False,
                  get_hexagon="h3", get_fill_color="[255,255,100,50]", get_line_color=[255,255,255], line_width_min_pixels=2)

view_state = pdk.ViewState(latitude=40.4168, longitude=-3.7038, zoom=14, bearing=0, pitch=30)

r = pdk.Deck(layers =[layer], initial_view_state=view_state, tooltip={"text":"Fake Text"})

# %%
r
# Out:
# {
#   "initialViewState": {
#     "bearing": 0,
#     "latitude": 40.4168,
#     "longitude": -3.7038,
#     "pitch": 30,
#     "zoom": 14
#   },
#   "layers": [
#     {
#       "@@type": "H3HexagonLayer",
#       "data": [
#         {
#           "Avg": 23.915277777777778,
#           "Estacion": 4,
#           "Latitud": 40.4238823,
#           "Longitud": -3.7122567,
#           "h3": "87390cb1bffffff"
#         },
#         {
#           "Avg": 27.686111111111114,
#           "Estacion": 8,
#           "Latitud": 40.4215533,
#           "Longitud": -3.6823158,
#           "h3": "87390ca26ffffff"
#         },
#         {
#           "Avg": 24.77638888888889,
#           "Estacion": 11,
#           "Latitud": 40.4514734,
#           "Longitud": -3.6773491,
#           "h3": "87390ca24ffffff"
#         },
#         {
#           "Avg": 21.52638888888889,
#           "Estacion": 16,
#           "Latitud": 40.4400457,
#           "Longitud": -3.6392422,
#           "h3": "87390ca25ffffff"
#         },
#         {
#           "Avg": 30.92777777777778,
#           "Estacion": 17,
#           "Latitud": 40.347147,
#           "Longitud": -3.7133167,
#           "h3": "87390cb89ffffff"
#         },
#         {
#           "Avg": 20.720833333333335,
#           "Estacion": 18,
#           "Latitud": 40.3947825,
#           "Longitud": -3.7318356,
#           "h3": "87390cba9ffffff"
#         },
#         {
#           "Avg": 12.198611111111111,
#           "Estacion": 24,
#           "Latitud": 40.4193577,
#           "Longitud": -3.7473445,
#           "h3": "87390cbadffffff"
#         },
#         {
#           "Avg": 28.345833333333335,
#           "Estacion": 27,
#           "Latitud": 40.4769179,
#           "Longitud": -3.5800258,
#           "h3": "87390cb51ffffff"
#         },
#         {
#           "Avg": 37.26944444444444,
#           "Estacion": 35,
#           "Latitud": 40.4192091,
#           "Longitud": -3.7031662,
#           "h3": "87390cb1bffffff"
#         },
#         {
#           "Avg": 22.60972222222222,
#           "Estacion": 36,
#           "Latitud": 40.4079517,
#           "Longitud": -3.6453104,
#           "h3": "87390ca22ffffff"
#         },
#         {
#           "Avg": 20.6375,
#           "Estacion": 38,
#           "Latitud": 40.4455439,
#           "Longitud": -3.7071303,
#           "h3": "87390cb19ffffff"
#         },
#         {
#           "Avg": 22.623611111111114,
#           "Estacion": 39,
#           "Latitud": 40.4782322,
#           "Longitud": -3.7115364,
#           "h3": "87390cb0effffff"
#         },
#         {
#           "Avg": 23.975,
#           "Estacion": 40,
#           "Latitud": 40.3881478,
#           "Longitud": -3.6515286,
#           "h3": "87390ca31ffffff"
#         },
#         {
#           "Avg": 24.875,
#           "Estacion": 47,
#           "Latitud": 40.3980991,
#           "Longitud": -3.6868138,
#           "h3": "87390ca35ffffff"
#         },
#         {
#           "Avg": 22.95277777777778,
#           "Estacion": 48,
#           "Latitud": 40.4398904,
#           "Longitud": -3.6903729,
#           "h3": "87390cb19ffffff"
#         },
#         {
#           "Avg": 15.341666666666667,
#           "Estacion": 49,
#           "Latitud": 40.4144444,
#           "Longitud": -3.6824999,
#           "h3": "87390ca35ffffff"
#         },
#         {
#           "Avg": 24.806944444444447,
#           "Estacion": 50,
#           "Latitud": 40.4655841,
#           "Longitud": -3.6887449,
#           "h3": "87390cb0affffff"
#         },
#         {
#           "Avg": 25.709722222222222,
#           "Estacion": 54,
#           "Latitud": 40.3730118,
#           "Longitud": -3.6121394,
#           "h3": "87390ca00ffffff"
#         },
#         {
#           "Avg": 25.019444444444446,
#           "Estacion": 55,
#           "Latitud": 40.4623628,
#           "Longitud": -3.5805649,
#           "h3": "87390cb53ffffff"
#         },
#         {
#           "Avg": 29.716666666666665,
#           "Estacion": 56,
#           "Latitud": 40.3850336,
#           "Longitud": -3.7187679,
#           "h3": "87390ca36ffffff"
#         },
#         {
#           "Avg": 17.955555555555556,
#           "Estacion": 57,
#           "Latitud": 40.4942012,
#           "Longitud": -3.6605173,
#           "h3": "87390cb09ffffff"
#         },
#         {
#           "Avg": 9.844444444444443,
#           "Estacion": 58,
#           "Latitud": 40.5180701,
#           "Longitud": -3.7746101,
#           "h3": "87390cb04ffffff"
#         },
#         {
#           "Avg": 18.083333333333332,
#           "Estacion": 59,
#           "Latitud": 40.4607255,
#           "Longitud": -3.6163407,
#           "h3": "87390cb52ffffff"
#         },
#         {
#           "Avg": 15.20138888888889,
#           "Estacion": 60,
#           "Latitud": 40.5005477,
#           "Longitud": -3.6897308,
#           "h3": "87390cb0cffffff"
#         },
#         {
#           "Avg": 22.689351851851853,
#           "Estacion": 90,
#           "Latitud": 40.46312006666667,
#           "Longitud": -3.7024705333333334,
#           "h3": "87390cb1dffffff"
#         },
#         {
#           "Avg": 22.501851851851853,
#           "Estacion": 91,
#           "Latitud": 40.43643886666666,
#           "Longitud": -3.7032533,
#           "h3": "87390cb19ffffff"
#         },
#         {
#           "Avg": 21.795370370370375,
#           "Estacion": 92,
#           "Latitud": 40.47933916666667,
#           "Longitud": -3.6869328666666665,
#           "h3": "87390cb08ffffff"
#         },
#         {
#           "Avg": 20.27175925925926,
#           "Estacion": 93,
#           "Latitud": 40.46880003333333,
#           "Longitud": -3.6514023666666664,
#           "h3": "87390cb0bffffff"
#         },
#         {
#           "Avg": 18.056944444444444,
#           "Estacion": 94,
#           "Latitud": 40.421620000000004,
#           "Longitud": -3.7298006,
#           "h3": "87390cb1affffff"
#         },
#         {
#           "Avg": 22.797916666666666,
#           "Estacion": 95,
#           "Latitud": 40.3964408,
#           "Longitud": -3.7093247,
#           "h3": "87390ca34ffffff"
#         },
#         {
#           "Avg": 26.84583333333333,
#           "Estacion": 96,
#           "Latitud": 40.3865907,
#           "Longitud": -3.68514825,
#           "h3": "87390ca30ffffff"
#         },
#         {
#           "Avg": 16.418055555555554,
#           "Estacion": 97,
#           "Latitud": 40.4324508,
#           "Longitud": -3.7272374,
#           "h3": "87390cb18ffffff"
#         }
#       ],
#       "extruded": false,
#       "filled": true,
#       "getFillColor": "@@=[255,255,100,50]",
#       "getHexagon": "@@=h3",
#       "getLineColor": [
#         255,
#         255,
#         255
#       ],
#       "id": "ce9e985e-3e71-4dd0-b941-9bcf2693d2ef",
#       "lineWidthMinPixels": 2,
#       "pickable": true,
#       "stroked": true
#     }
#   ],
#   "mapProvider": "carto",
#   "mapStyle": "https://basemaps.cartocdn.com/gl/dark-matter-gl-style/style.json",
#   "views": [
#     {
#       "@@type": "MapView",
#       "controller": true
#     }
#   ]
# }

# %%
prueba_map.to_csv('../clean_visuals/H3_NO2_2023.csv', index = False)

# %%
prueba_map.head()
# Out:
#    Estacion        Avg    Latitud  Longitud               h3
# 0         4  23.915278  40.423882 -3.712257  87390cb1bffffff
# 1         8  27.686111  40.421553 -3.682316  87390ca26ffffff
# 2        11  24.776389  40.451473 -3.677349  87390ca24ffffff
# 3        16  21.526389  40.440046 -3.639242  87390ca25ffffff
# 4        17  30.927778  40.347147 -3.713317  87390cb89ffffff

# %% [markdown]
# ### Marcadores estaciones

# %%
# Crea un mapa centrado en Madrid
mapa = folium.Map(location=[40.4168, -3.7038], zoom_start=12)  # Coordenadas de Madrid

# Itera sobre el DataFrame para agregar marcadores al mapa
for index, row in prueba_map.iterrows():
    folium.Marker([row['Latitud'], row['Longitud']], popup=row['Avg']).add_to(mapa)

# Muestra el mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abd4f8c6decc589750cae0dd0a77365a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abd4f8c6decc589750cae0dd0a77365a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_abd4f8c6decc589750cae0dd0a77365a = L.map(
#                 &quot;map_abd4f8c6decc589750cae0dd0a77365a&quot;,
#                 {
#                     center: [40.4168, -3.7038],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e0e61d624d61ccf1541540b8cb32dd0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8e0e61d624d61ccf1541540b8cb32dd0.addTo(map_abd4f8c6decc589750cae0dd0a77365a);
#
#
#             var marker_1601213c3d240cf3fd2df6c6b4b3786a = L.marker(
#                 [40.4238823, -3.7122567],
#                 {}
#             ).addTo(map_abd4f8c6decc589750cae0dd0a77365a);
#
#
#         var popup_1c7d16f307a728640fde0e1236115769 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f0158954f7ffad710489e17eec40cce8 = $(`&lt;div id=&quot;html_f0158954f7ffad710489e17eec40cce8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;23.915277777777778&lt;/div&gt;`)[0];
#                 popup_1c7d16f307a728640fde0e1236115769.setContent(html_f0158954f7ffad710489e17eec40cce8);
#
#
#
#         marker_1601213c3d240cf3fd2df6c6b4b3786a.bindPopup(popup_1c7d16f307a728640fde0e1236115769)
#         ;
#
#
#
#
#             var marker_e24864112532c2162a411be09678f831 = L.marker(
#                 [40.4215533, -3.6823158],
#                 {}
#             ).addTo(map_abd4f8c6decc589750cae0dd0a77365a);
#
#
#         var popup_215aef9152d7b7f6a80aadfad6e971e0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bcc990a570c6da5e550dd0e2f854a3fc = $(`&lt;div id=&quot;html_bcc990a570c6da5e550dd0e2f854a3fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;27.686111111111114&lt;/div&gt;`)[0];
#                 popup_215aef9152d7b7f6a80aadfad6e971e0.setContent(html_bcc990a570c6da5e550dd0e2f854a3fc);
#
#
#
#         marker_e24864112532c2162a411be09678f831.bindPopup(popup_215aef9152d7b7f6a80aadfad6e971e0)
#         ;
#
#
#
#
#             var marker_b119c1622a8f4dda85599fcba8c987ea = L.marker(
#                 [40.4514734, -3.6773491],
#                 {}
#             ).addTo(map_abd4f8c6decc589750cae0dd0a77365a);
#
#
#         var popup_cf398abf0f50d484e4778608d031cffd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b7156356ce9a16ef77eba4fe465f8063 = $(`&lt;div id=&quot;html_b7156356ce9a16ef77eba4fe465f8063&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;24.77638888888889&lt;/div&gt;`)[0];
#                 popup_cf398abf0f50d484e4778608d031cffd.setContent(html_b7156356ce9a16ef77eba4fe465f8063);
#
#
#
#         marker_b119c1622a8f4dda85599fcba8c987ea.bindPopup(popup_cf398abf0f50d484e4778608d031cffd)
#         ;
#
#
#
#
#             var marker_facb63ce2f0bb01999872bdaa0ec0444 = L.marker(
#                 [40.4400457, -3.6392422],
#                 {}
#             ).addTo(map_abd4f8c6decc589750cae0dd0a77365a);
#
#
#         var popup_39a9ff5ea55ec99d28d027c479964b75 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_45dfc94fc573ab69c30909f0109ec2d5 = $(`&lt;div id=&quot;html_45dfc94fc573ab69c30909f0109ec2d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;21.52638888888889&lt;/div&gt;`)[0];
#                 popup_39a9ff5ea55ec99d28d027c479964b75.setContent(html_45dfc94fc573ab69c30909f0109ec2d5);
#
#
#
#         marker_facb63ce2f0bb01999872bdaa0ec0444.bindPopup(popup_39a9ff5ea55ec99d28d027c479964b75)
#         ;
#
#
#
#
#             var marker_24e7c618d9ee366867f26dd3ba24661a = L.marker(
#                 [40.347147, -3.7133167],
#                 {}
#             ).addTo(map_abd4f8c6decc589750cae0dd0a77365a);
#
#
#         var popup_043a0bb51c47703cc37619ae96cf98f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_65e237f2e2b62cb6d49741a321123e56 = $(`&lt;div id=&quot;html_65e237f2e2b62cb6d49741a321123e56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;30.92777777777778&lt;/div&gt;`)[0];
#                 popup_043a0bb51c47703cc37619ae96cf98f0.setContent(html_65e237f2e2b62cb6d49741a321123e56);
#
#
#
#         marker_24e7c618d9ee366867f26dd3ba24661a.bindPopup(popup_043a0bb51c47703cc37619ae96cf98f0)
#         ;
#
#
#
#
#             var marker_b238bb0e62791e5ee0c0ae4afa7ec5f8 = L.marker(
#                 [40.3947825, -3.7318356],
#                 {}
#             ).addTo(map_abd4f8c6decc

# %% [markdown]
# ### Heat map folium

# %%
from folium.plugins import HeatMap

# Supongamos que tienes una lista de listas con las coordenadas y el valor promedio (avg) de tu DataFrame
datos_mapa = [[row['Latitud'], row['Longitud'], row['Avg']] for index, row in prueba_map.iterrows()]

# Normaliza los valores de avg para que estén en el rango [0, 1] (opcional, dependiendo de tus datos)
valor_min = prueba_map['Avg'].min()
valor_max = prueba_map['Avg'].max()
datos_mapa = [[fila[0], fila[1], (fila[2] - valor_min) / (valor_max - valor_min)] for fila in datos_mapa]

# Define tu paleta de colores personalizada
colores = ['lime', 'yellow', 'red']  # Cambia estos colores según tu preferencia
mapa_calor = HeatMap(datos_mapa, gradient={0.0: colores[0], 0.5: colores[1], 1.0: colores[2]}, radius=40, blur=15)

# Crea un mapa centrado en Madrid
mapa = folium.Map(location=[40.4168, -3.7038], zoom_start=12)  # Coordenadas de Madrid

# Agrega el mapa de calor al mapa principal
mapa.add_child(mapa_calor)

# Muestra el mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0fb4ff1c4c717445eadc2b501e9f564 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0fb4ff1c4c717445eadc2b501e9f564&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0fb4ff1c4c717445eadc2b501e9f564 = L.map(
#                 &quot;map_f0fb4ff1c4c717445eadc2b501e9f564&quot;,
#                 {
#                     center: [40.4168, -3.7038],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_524c1d4aa1ac8841978f1533083da05e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_524c1d4aa1ac8841978f1533083da05e.addTo(map_f0fb4ff1c4c717445eadc2b501e9f564);
#
#
#             var heat_map_72c3ff77571a50188d56c4130ee76f2d = L.heatLayer(
#                 [[40.4238823, -3.7122567, 0.5130659374050441], [40.4215533, -3.6823158, 0.6505621391674264], [40.4514734, -3.6773491, 0.5444647017117392], [40.4400457, -3.6392422, 0.42595968803808376], [40.347147, -3.7133167, 0.7687632938316623], [40.3947825, -3.7318356, 0.39658665046085295], [40.4193577, -3.7473445, 0.08584017016104532], [40.4769179, -3.5800258, 0.6746176440798137], [40.4192091, -3.7031662, 1.0], [40.4079517, -3.6453104, 0.4654613592626355], [40.4455439, -3.7071303, 0.39354806036665657], [40.4782322, -3.7115364, 0.4659677909450017], [40.3881478, -3.6515286, 0.5152435936392182], [40.3980991, -3.6868138, 0.5480603666565381], [40.4398904, -3.6903729, 0.47797022181707705], [40.4144444, -3.6824999, 0.20044565988048219], [40.4655841, -3.6887449, 0.5455788514129446], [40.3730118, -3.6121394, 0.5784969107667377], [40.4623628, -3.5805649, 0.553327256153145], [40.3850336, -3.7187679, 0.7246024511293426], [40.4942012, -3.6605173, 0.2957561025017726], [40.5180701, -3.7746101, 0.0], [40.4607255, -3.6163407, 0.3004152739795402], [40.5005477, -3.6897308, 0.19533069988858512], [40.46312006666667, -3.7024705333333334, 0.468364900908201], [40.43643886666666, -3.7032533, 0.4615280731962593], [40.47933916666667, -3.6869328666666665, 0.43576758161990636], [40.46880003333333, -3.6514023666666664, 0.38021202606435067], [40.421620000000004, -3.7298006, 0.2994530537830447], [40.3964408, -3.7093247, 0.4723235085586955], [40.3865907, -3.68514825, 0.6199230223842804], [40.4324508, -3.7272374, 0.23969411526385093]],
#                 {&quot;blur&quot;: 15, &quot;gradient&quot;: {&quot;0.0&quot;: &quot;lime&quot;, &quot;0.5&quot;: &quot;yellow&quot;, &quot;1.0&quot;: &quot;red&quot;}, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 40}
#             );
#
#
#             heat_map_72c3ff77571a50188d56c4130ee76f2d.addTo(map_f0fb4ff1c4c717445eadc2b501e9f564);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
prueba_map.head()
# Out:
#    Estacion        Avg    Latitud  Longitud               h3
# 0         4  23.915278  40.423882 -3.712257  87390cb1bffffff
# 1         8  27.686111  40.421553 -3.682316  87390ca26ffffff
# 2        11  24.776389  40.451473 -3.677349  87390ca24ffffff
# 3        16  21.526389  40.440046 -3.639242  87390ca25ffffff
# 4        17  30.927778  40.347147 -3.713317  87390cb89ffffff

# %% [markdown]
# ## Barrios MAD

# %%
# Ruta al archivo GeoJSON
ruta_archivo = '../data/madrid-districts.geojson'

# Carga el archivo GeoJSON en un GeoDataFrame
mad = gpd.read_file(ruta_archivo)

# %%
mad
# Out:
#                    name  cartodb_id                created_at  \
# 0                Centro           1 2013-12-02 07:20:26+01:00
# 1            Arganzuela           2 2013-12-02 07:20:26+01:00
# 2                Retiro           3 2013-12-02 07:20:26+01:00
# 3             Salamanca           4 2013-12-02 07:20:26+01:00
# 4             Chamartin           5 2013-12-02 07:20:26+01:00
# 5                Tetuan           6 2013-12-02 07:20:26+01:00
# 6              Chamberi           7 2013-12-02 07:20:26+01:00
# 7   Fuencarral-El Pardo           8 2013-12-02 07:20:26+01:00
# 8       Moncloa-Aravaca           9 2013-12-02 07:20:26+01:00
# 9                Latina          10 2013-12-02 07:20:26+01:00
# 10          Carabanchel          11 2013-12-02 07:20:26+01:00
# 11                Usera          12 2013-12-02 07:20:26+01:00
# 12   Puente de Vallecas          13 2013-12-02 07:20:26+01:00
# 13            Moratalaz          14 2013-12-02 07:20:26+01:00
# 14        Ciudad Lineal          15 2013-12-02 07:20:26+01:00
# 15            Hortaleza          16 2013-12-02 07:20:26+01:00
# 16           Villaverde          17 2013-12-02 07:20:26+01:00
# 17    Villa de Vallecas          18 2013-12-02 07:20:26+01:00
# 18            Vicalvaro          19 2013-12-02 07:20:26+01:00
# 19             San Blas          20 2013-12-02 07:20:26+01:00
# 20              Barajas          21 2013-12-02 07:20:26+01:00
#
#                   updated_at  \
# 0  2013-12-02 07:20:26+01:00
# 1  2013-12-02 07:20:26+01:00
# 2  2013-12-02 07:20:26+01:00
# 3  2013-12-02 07:20:26+01:00
# 4  2013-12-02 07:20:26+01:00
# 5  2013-12-02 07:20:26+01:00
# 6  2013-12-02 07:20:26+01:00
# 7  2013-12-02 07:20:26+01:00
# 8  2013-12-02 07:20:26+01:00
# 9  2013-12-02 07:20:26+01:00
# 10 2013-12-02 07:20:26+01:00
# 11 2013-12-02 07:20:26+01:00
# 12 2013-12-02 07:20:26+01:00
# 13 2013-12-02 07:20:26+01:00
# 14 2013-12-02 07:20:26+01:00
# 15 2013-12-02 07:20:26+01:00
# 16 2013-12-02 07:20:26+01:00
# 17 2013-12-02 07:20:26+01:00
# 18 2013-12-02 07:20:26+01:00
# 19 2013-12-02 07:20:26+01:00
# 20 2013-12-02 07:20:26+01:00
#
#                                              geometry
# 0   MULTIPOLYGON (((-3.69185 40.40853, -3.69189 40...
# 1   MULTIPOLYGON (((-3.70258 40.40638, -3.70166 40...
# 2   MULTIPOLYGON (((-3.66279 40.40971, -3.66384 40...
# 3   MULTIPOLYGON (((-3.65809 40.43945, -3.65828 40...
# 4   MULTIPOLYGON (((-3.67231 40.48388, -3.67237 40...
# 5   MULTIPOLYGON (((-3.69633 40.47572, -3.69619 40...
# 6   MULTIPOLYGON (((-3.68991 40.44737, -3.69048 40...
# 7   MULTIPOLYGON (((-3.64131 40.63922, -3.64118 40...
# 8   MULTIPOLYGON (((-3.79973 40.47063, -3.79887 40...
# 9   MULTIPOLYGON (((-3.72130 40.41256, -3.72051 40...
# 10  MULTIPOLYGON (((-3.72346 40.40622, -3.72345 40...
# 11  MULTIPOLYGON (((-3.68189 40.36592, -3.68190 40...
# 12  MULTIPOLYGON (((-3.67705 40.36180, -3.67706 40...
# 13  MULTIPOLYGON (((-3.64158 40.41569, -3.63964 40...
# 14  MULTIPOLYGON (((-3.62058 40.41671, -3.62031 40...
# 15  MULTIPOLYGON (((-3.65114 40.51230, -3.65095 40...
# 16  MULTIPOLYGON (((-3.70235 40.36475, -3.70193 40...
# 17  MULTIPOLYGON (((-3.60631 40.38820, -3.60524 40...
# 18  MULTIPOLYGON (((-3.57633 40.41484, -3.57159 40...
# 19  MULTIPOLYGON (((-3.59198 40.45123, -3.59194 40...
# 20  MULTIPOLYGON (((-3.56045 40.51234, -3.56036 40...

# %% [markdown]
# ### Heat Map

# %%
prueba_map
# Out:
#     Estacion        Avg    Latitud  Longitud               h3
# 0          4  23.915278  40.423882 -3.712257  87390cb1bffffff
# 1          8  27.686111  40.421553 -3.682316  87390ca26ffffff
# 2         11  24.776389  40.451473 -3.677349  87390ca24ffffff
# 3         16  21.526389  40.440046 -3.639242  87390ca25ffffff
# 4         17  30.927778  40.347147 -3.713317  87390cb89ffffff
# 5         18  20.720833  40.394782 -3.731836  87390cba9ffffff
# 6         24  12.198611  40.419358 -3.747345  87390cbadffffff
# 7         27  28.345833  40.476918 -3.580026  87390cb51ffffff
# 8         35  37.269444  40.419209 -3.703166  87390cb1bffffff
# 9         36  22.609722  40.407952 -3.645310  87390ca22ffffff
# 10        38  20.637500  40.445544 -3.707130  87390cb19ffffff
# 11        39  22.623611  40.478232 -3.711536  87390cb0effffff
# 12        40  23.975000  40.388148 -3.651529  87390ca31ffffff
# 13        47  24.875000  40.398099 -3.686814  87390ca35ffffff
# 14        48  22.952778  40.439890 -3.690373  87390cb19ffffff
# 15        49  15.341667  40.414444 -3.682500  87390ca35ffffff
# 16        50  24.806944  40.465584 -3.688745  87390cb0affffff
# 17        54  25.709722  40.373012 -3.612139  87390ca00ffffff
# 18        55  25.019444  40.462363 -3.580565  87390cb53ffffff
# 19        56  29.716667  40.385034 -3.718768  87390ca36ffffff
# 20        57  17.955556  40.494201 -3.660517  87390cb09ffffff
# 21        58   9.844444  40.518070 -3.774610  87390cb04ffffff
# 22        59  18.083333  40.460726 -3.616341  87390cb52ffffff
# 23        60  15.201389  40.500548 -3.689731  87390cb0cffffff
# 24        90  22.689352  40.463120 -3.702471  87390cb1dffffff
# 25        91  22.501852  40.436439 -3.703253  87390cb19ffffff
# 26        92  21.795370  40.479339 -3.686933  87390cb08ffffff
# 27        93  20.271759  40.468800 -3.651402  87390cb0bffffff
# 28        94  18.056944  40.421620 -3.729801  87390cb1affffff
# 29        95  22.797917  40.396441 -3.709325  87390ca34ffffff
# 30        96  26.845833  40.386591 -3.685148  87390ca30ffffff
# 31        97  16.418056  40.432451 -3.727237  87390cb18ffffff

# %%
import pandas as pd
import folium
from folium import plugins

# Suponiendo que 'prueba_map' es tu DataFrame con columnas 'LATITUD', 'LONGITUD', y 'avg'

# Cargar tu DataFrame
# prueba_map = pd.read_csv('archivo.csv')  # Si tus datos están en un archivo CSV, por ejemplo

# Coordenadas de Madrid
latitud_madrid = 40.4168
longitud_madrid = -3.7038

# Crear un mapa centrado en Madrid
mapa = folium.Map(location=[latitud_madrid, longitud_madrid], zoom_start=10)

# Crear una lista de listas con las coordenadas y valores de NO2
data = prueba_map[['Latitud', 'Longitud', 'Avg']].values.tolist()

# Crear el mapa de calor con HeatMap
mapa.add_child(plugins.HeatMap(data=data, radius=30))

# Mostrar el mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e63df186b63188568f9dc505e909b2db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e63df186b63188568f9dc505e909b2db&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e63df186b63188568f9dc505e909b2db = L.map(
#                 &quot;map_e63df186b63188568f9dc505e909b2db&quot;,
#                 {
#                     center: [40.4168, -3.7038],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_25df0ee628e0d9354e86d30632a1e562 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_25df0ee628e0d9354e86d30632a1e562.addTo(map_e63df186b63188568f9dc505e909b2db);
#
#
#             var heat_map_61d8bfb69e9e450e1c8ed3e066e7a81d = L.heatLayer(
#                 [[40.4238823, -3.7122567, 23.915277777777778], [40.4215533, -3.6823158, 27.686111111111114], [40.4514734, -3.6773491, 24.77638888888889], [40.4400457, -3.6392422, 21.52638888888889], [40.347147, -3.7133167, 30.92777777777778], [40.3947825, -3.7318356, 20.720833333333335], [40.4193577, -3.7473445, 12.198611111111111], [40.4769179, -3.5800258, 28.345833333333335], [40.4192091, -3.7031662, 37.26944444444444], [40.4079517, -3.6453104, 22.60972222222222], [40.4455439, -3.7071303, 20.6375], [40.4782322, -3.7115364, 22.623611111111114], [40.3881478, -3.6515286, 23.975], [40.3980991, -3.6868138, 24.875], [40.4398904, -3.6903729, 22.95277777777778], [40.4144444, -3.6824999, 15.341666666666667], [40.4655841, -3.6887449, 24.806944444444447], [40.3730118, -3.6121394, 25.709722222222222], [40.4623628, -3.5805649, 25.019444444444446], [40.3850336, -3.7187679, 29.716666666666665], [40.4942012, -3.6605173, 17.955555555555556], [40.5180701, -3.7746101, 9.844444444444443], [40.4607255, -3.6163407, 18.083333333333332], [40.5005477, -3.6897308, 15.20138888888889], [40.46312006666667, -3.7024705333333334, 22.689351851851853], [40.43643886666666, -3.7032533, 22.501851851851853], [40.47933916666667, -3.6869328666666665, 21.795370370370375], [40.46880003333333, -3.6514023666666664, 20.27175925925926], [40.421620000000004, -3.7298006, 18.056944444444444], [40.3964408, -3.7093247, 22.797916666666666], [40.3865907, -3.68514825, 26.84583333333333], [40.4324508, -3.7272374, 16.418055555555554]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 30}
#             );
#
#
#             heat_map_61d8bfb69e9e450e1c8ed3e066e7a81d.addTo(map_e63df186b63188568f9dc505e909b2db);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Zonas de influencia con marcadores

# %%
prueba_map.head()
# Out:
#    Estacion        Avg    Latitud  Longitud               h3
# 0         4  23.915278  40.423882 -3.712257  87390cb1bffffff
# 1         8  27.686111  40.421553 -3.682316  87390ca26ffffff
# 2        11  24.776389  40.451473 -3.677349  87390ca24ffffff
# 3        16  21.526389  40.440046 -3.639242  87390ca25ffffff
# 4        17  30.927778  40.347147 -3.713317  87390cb89ffffff

# %%
prueba_map
# Out:
#     Estacion        Avg    Latitud  Longitud               h3
# 0          4  23.915278  40.423882 -3.712257  87390cb1bffffff
# 1          8  27.686111  40.421553 -3.682316  87390ca26ffffff
# 2         11  24.776389  40.451473 -3.677349  87390ca24ffffff
# 3         16  21.526389  40.440046 -3.639242  87390ca25ffffff
# 4         17  30.927778  40.347147 -3.713317  87390cb89ffffff
# 5         18  20.720833  40.394782 -3.731836  87390cba9ffffff
# 6         24  12.198611  40.419358 -3.747345  87390cbadffffff
# 7         27  28.345833  40.476918 -3.580026  87390cb51ffffff
# 8         35  37.269444  40.419209 -3.703166  87390cb1bffffff
# 9         36  22.609722  40.407952 -3.645310  87390ca22ffffff
# 10        38  20.637500  40.445544 -3.707130  87390cb19ffffff
# 11        39  22.623611  40.478232 -3.711536  87390cb0effffff
# 12        40  23.975000  40.388148 -3.651529  87390ca31ffffff
# 13        47  24.875000  40.398099 -3.686814  87390ca35ffffff
# 14        48  22.952778  40.439890 -3.690373  87390cb19ffffff
# 15        49  15.341667  40.414444 -3.682500  87390ca35ffffff
# 16        50  24.806944  40.465584 -3.688745  87390cb0affffff
# 17        54  25.709722  40.373012 -3.612139  87390ca00ffffff
# 18        55  25.019444  40.462363 -3.580565  87390cb53ffffff
# 19        56  29.716667  40.385034 -3.718768  87390ca36ffffff
# 20        57  17.955556  40.494201 -3.660517  87390cb09ffffff
# 21        58   9.844444  40.518070 -3.774610  87390cb04ffffff
# 22        59  18.083333  40.460726 -3.616341  87390cb52ffffff
# 23        60  15.201389  40.500548 -3.689731  87390cb0cffffff
# 24        90  22.689352  40.463120 -3.702471  87390cb1dffffff
# 25        91  22.501852  40.436439 -3.703253  87390cb19ffffff
# 26        92  21.795370  40.479339 -3.686933  87390cb08ffffff
# 27        93  20.271759  40.468800 -3.651402  87390cb0bffffff
# 28        94  18.056944  40.421620 -3.729801  87390cb1affffff
# 29        95  22.797917  40.396441 -3.709325  87390ca34ffffff
# 30        96  26.845833  40.386591 -3.685148  87390ca30ffffff
# 31        97  16.418056  40.432451 -3.727237  87390cb18ffffff

# %%
from branca.colormap import LinearColormap
import folium
import h3

nivel_resolucion = 7  # Puedes ajustar este valor según la resolución deseada

def calcular_influencia(distancia):
    # Aquí puedes establecer tu fórmula de influencia basada en la distancia
    # Por ejemplo, una función exponencial inversa podría ser: 
    influencia = 1 / (distancia + 1)  # Puedes ajustar esta fórmula según tus necesidades
    return influencia


# Crear un mapa de Folium centrado en Madrid
madrid_coords = [40.4168, -3.7038]
mapa = folium.Map(location=madrid_coords, zoom_start=12)

# Encontrar el rango de valores de avg para establecer la escala de colores
max_avg = prueba_map['Avg'].max()
min_avg = prueba_map['Avg'].min()

# Crear un colormap lineal entre rojo y verde basado en los valores de avg, pero invertido
colormap = LinearColormap(colors=['green', 'yellow', 'red'], vmin=min_avg, vmax=max_avg).to_step(10)

# Iterar sobre cada fila del DataFrame
for index, row in prueba_map.iterrows():
    # Obtener coordenadas de la fila actual
    latitud = row['Latitud']
    longitud = row['Longitud']
    valor_so2 = row['Avg']  # Valor de SO2 en esta fila
    estacion = row['Estacion']  # Nombre de la estación
    
    # Convertir coordenadas a hexágono H3
    hexagono_central = h3.geo_to_h3(latitud, longitud, nivel_resolucion)
    
    # Obtener los hexágonos vecinos a una distancia determinada (por ejemplo, 1 nivel de distancia)
    nivel_distancia = 10
    hexagonos_vecinos = h3.k_ring(hexagono_central, nivel_distancia)
    
    # Calcular la influencia de SO2 para cada hexágono vecino
    influencia_total = 0
    for hexagono_vecino in hexagonos_vecinos:
        # Obtener la distancia entre el hexágono central y el vecino
        distancia_central_vecino = h3.h3_distance(hexagono_central, hexagono_vecino)
        
        # Calcular la influencia exponencial en función de la distancia
        influencia = calcular_influencia(distancia_central_vecino)
        
        # Sumar la influencia ponderada por el valor de SO2
        influencia_total += influencia * valor_so2
    
    # Calcular el promedio de influencia total para los hexágonos vecinos
    influencia_promedio = influencia_total / len(hexagonos_vecinos)
    
    # Crear polígonos para los hexágonos H3 y agregar al mapa con el color correspondiente
    folium.GeoJson(
        {
            'type': 'Feature',
            'geometry': {
                'type': 'Polygon',
                'coordinates': [h3.h3_to_geo_boundary(hexagono_central, geo_json=True)]
            },
            'properties': {'tooltip': f"Avg SO2: {valor_so2}", 'style': {'fillColor': colormap(valor_so2), 'fillOpacity': 0.6}}
        },
        tooltip=f"Avg SO2: {valor_so2}"
    ).add_to(mapa)
    
    # Agregar marcador para la coordenada actual con el nombre de la estación como popup
    folium.Marker(
        location=[latitud, longitud],
        popup=f'Estación: {estacion}',
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(mapa)

# Guardar el mapa como un archivo HTML para visualización interactiva
mapa.save('../clean_visuals/Estaciones y zona de influencia.html')

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed96972dba48201afeb64b5b5f8bb4a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed96972dba48201afeb64b5b5f8bb4a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ed96972dba48201afeb64b5b5f8bb4a4 = L.map(
#                 &quot;map_ed96972dba48201afeb64b5b5f8bb4a4&quot;,
#                 {
#                     center: [40.4168, -3.7038],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_618c8e967a35f04f41fe6c88a722eb86 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_618c8e967a35f04f41fe6c88a722eb86.addTo(map_ed96972dba48201afeb64b5b5f8bb4a4);
#
#
#
#         function geo_json_91e17d9b76ec5a2c1d7077338124aa57_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_91e17d9b76ec5a2c1d7077338124aa57 = L.geoJson(null, {
#                 onEachFeature: geo_json_91e17d9b76ec5a2c1d7077338124aa57_onEachFeature,
#
#         });
#
#         function geo_json_91e17d9b76ec5a2c1d7077338124aa57_add (data) {
#             geo_json_91e17d9b76ec5a2c1d7077338124aa57
#                 .addData(data);
#         }
#             geo_json_91e17d9b76ec5a2c1d7077338124aa57_add({&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-3.705557809987163, 40.43366785857172], [-3.717901962720989, 40.425149335812335], [-3.7146082965667695, 40.41218634597263], [-3.698976048021155, 40.40774273343614], [-3.6866346617342396, 40.416259836119124], [-3.689922757339867, 40.429221971039134], [-3.705557809987163, 40.43366785857172]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;style&quot;: {&quot;fillColor&quot;: &quot;#ffe300ff&quot;, &quot;fillOpacity&quot;: 0.6}, &quot;tooltip&quot;: &quot;Avg SO2: 23.915277777777778&quot;}, &quot;type&quot;: &quot;Feature&quot;});
#
#
#
#             geo_json_91e17d9b76ec5a2c1d7077338124aa57.bindTooltip(
#                 `&lt;div&gt;
#                      Avg SO2: 23.915277777777778
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             geo_json_91e17d9b76ec5a2c1d7077338124aa57.addTo(map_ed96972dba48201afeb64b5b5f8bb4a4);
#
#
#             var marker_67f508da95a2b287d9e195e31a2218e9 = L.marker(
#                 [40.4238823, -3.7122567],
#                 {}
#             ).addTo(map_ed96972dba48201afeb64b5b5f8bb4a4);
#
#
#             var icon_d30a7a73c873d644fc1146df1829d8e3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_67f508da95a2b287d9e195e31a2218e9.setIcon(icon_d30a7a73c873d644fc1146df1829d8e3);
#
#
#         var popup_40263b9a6beca88c7246ae46719f72e9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_03dc519c6dbc831abe04641383aa0083 = $(`&lt;div id=&quot;html_03dc519c6dbc831abe04641383aa0083&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estación: 4&lt;/div&gt;`)[0];
#                 popup_40263b9a6beca88c7246ae46719f72e9.setContent(html_03dc519c6dbc831abe04641383aa0083);
#
#
#
#         marker_67f508da95a2b287d9e195e31a2218e9.bindPopup(popup_40263b9a6beca88c7246ae46719f72e9)
#         ;
#
#
#
#
#
#         function geo_json_da3fa21531d32989802b030e351805ae_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_da3fa21531d32989802b030e351805ae = L.geoJson(null, {
#                 onEachFeature: geo_json_da3fa21531d32989802b030e351805ae_onEachFeature,
#
#         });
#
#         function geo_json_da3fa21531d32989802b030e351805ae_add (data) {
#             geo_json_da3fa21531d32989802b030e351805ae
#                 .addData(data);
#         }
#             geo_json_da3fa21531d32989802b030e351805ae_add({&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-3.677577671380749, 40.43773617762055], [-3.689922757339867, 40.429221971039134], [-3.6866346617342396, 40.416259836119124], [-3.6710070506337056, 40.41181276528148], [-3.6586647358543796, 40.42032555366394], [-3.6619472607919312, 40.43328683070742], [-3.677577671380749, 40.43773617762055]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;style&quot;: {&quot;fillColor&quot;: &quot;#ffaa00ff&quot;, &quot;fillOpacity&quot;: 0.6}, &quot;tooltip&quot;: &quot;Avg SO2: 27.686111111111114&quot;}, &quot;type&quot;: &quot;Feature&quot;});
#
#
#
#             geo_json_da3fa21531d32989802b030e351805ae.bindTooltip(
#                 `&lt;div&gt;
#                      Avg SO2: 27.686111111111114
#                  &lt;/div&gt;`,
