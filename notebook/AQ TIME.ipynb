# %% [markdown]
# # AQ TIME

# %%
import pandas as pd
import polars as pl
import folium
import h3
import matplotlib.pyplot as plt
import geopandas as gpd
from geopy.distance import geodesic

import os
from datetime import datetime
from tqdm import tqdm

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

pd.set_option('display.max_seq_items', None)

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Coordenadas estaciones

# %%
estaciones = pd.read_csv("../data/AytoMad/informacion_estaciones_red_calidad_aire.csv", sep=';')
estaciones.head()
# Out:
#      CODIGO  CODIGO_CORTO          ESTACION  \
# 0  28079004             4   Plaza de España
# 1  28079008             8  Escuelas Aguirre
# 2  28079011            11     Ramón y Cajal
# 3  28079016            16      Arturo Soria
# 4  28079017            17        Villaverde
#
#                                            DIRECCION LONGITUD_ETRS89  \
# 0                                    Plaza de España    3°42'43.91"O
# 1                    Entre C/ Alcalá y C/ O’ Donell     3°40'56.22"O
# 2   Avda. Ramón y Cajal  esq. C/ Príncipe de Vergara    3°40'38.50"O
# 3  C/ Arturo Soria  esq. C/  Vizconde de los Asilos     3°38'21.17"O
# 4                                   C/ Juan Peñalver    3°42'47.89"O
#
#   LATITUD_ETRS89  ALTITUD COD_TIPO        NOM_TIPO NO2  SO2   CO PM10 PM2_5  \
# 0  40°25'25.98"N      637       UT  Urbana tráfico   X    X    X  NaN   NaN
# 1  40°25'17.63"N      672       UT  Urbana tráfico   X    X    X    X     X
# ...

# %%
estaciones.columns = [col.capitalize() for col in estaciones.columns]

# %%
estaciones.head()
# Out:
#      Codigo  Codigo_corto          Estacion  \
# 0  28079004             4   Plaza de España
# 1  28079008             8  Escuelas Aguirre
# 2  28079011            11     Ramón y Cajal
# 3  28079016            16      Arturo Soria
# 4  28079017            17        Villaverde
#
#                                            Direccion Longitud_etrs89  \
# 0                                    Plaza de España    3°42'43.91"O
# 1                    Entre C/ Alcalá y C/ O’ Donell     3°40'56.22"O
# 2   Avda. Ramón y Cajal  esq. C/ Príncipe de Vergara    3°40'38.50"O
# 3  C/ Arturo Soria  esq. C/  Vizconde de los Asilos     3°38'21.17"O
# 4                                   C/ Juan Peñalver    3°42'47.89"O
#
#   Latitud_etrs89  Altitud Cod_tipo        Nom_tipo No2  So2   Co Pm10 Pm2_5  \
# 0  40°25'25.98"N      637       UT  Urbana tráfico   X    X    X  NaN   NaN
# 1  40°25'17.63"N      672       UT  Urbana tráfico   X    X    X    X     X
# ...

# %%
estaciones.columns
# Out:
# Index(['Codigo', 'Codigo_corto', 'Estacion', 'Direccion', 'Longitud_etrs89',
#        'Latitud_etrs89', 'Altitud', 'Cod_tipo', 'Nom_tipo', 'No2', 'So2', 'Co',
#        'Pm10', 'Pm2_5', 'O3', 'Btx', 'Cod_via', 'Via_clase', 'Via_par',
#        'Via_nombre', 'Fecha alta', 'Coordenada_x_etrs89',
#        'Coordenada_y_etrs89', 'Longitud', 'Latitud'],
#       dtype='object')

# %%
coords = estaciones.drop(['Codigo', 'Estacion', 'Direccion', 'Longitud_etrs89',
       'Latitud_etrs89', 'Altitud', 'Cod_tipo', 'Nom_tipo', 'No2', 'So2', 'Co',
       'Pm10', 'Pm2_5', 'O3', 'Btx', 'Cod_via', 'Via_clase', 'Via_par',
       'Via_nombre', 'Fecha alta', 'Coordenada_x_etrs89',
       'Coordenada_y_etrs89'], axis=1)

# %%
coords.head()
# Out:
#    Codigo_corto  Longitud    Latitud
# 0             4 -3.712257  40.423882
# 1             8 -3.682316  40.421553
# 2            11 -3.677349  40.451473
# 3            16 -3.639242  40.440046
# 4            17 -3.713317  40.347147

# %%
coords = coords.rename(columns={'Codigo_corto': 'Estacion'})

# %% [markdown]
# ### NO2 abril 2023

# %% [markdown]
# *NO2 es la magnitud 8*

# %%
df = pd.read_csv("../data/AytoMad/Anio23/abr_mo23.csv", sep=';')
df.head()
# Out:
#    PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  DIA  \
# 0         28         79         4         1  28079004_1_38  2023    4    1
# 1         28         79         4         1  28079004_1_38  2023    4    2
# 2         28         79         4         1  28079004_1_38  2023    4    3
# 3         28         79         4         1  28079004_1_38  2023    4    4
# 4         28         79         4         1  28079004_1_38  2023    4    5
#
#    H01 V01  H02 V02  H03 V03  H04 V04  H05 V05  H06 V06  H07 V07  H08 V08  \
# 0  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V
# 1  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V
# 2  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V
# 3  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  2.0   V
# 4  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  1.0   V  2.0   V
#
# ...

# %%
df2304 = df[df["MAGNITUD"] == 8]

# %%
df2304.head()
# Out:
#     PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  DIA  \
# 90         28         79         4         8   28079004_8_8  2023    4    1
# 91         28         79         4         8   28079004_8_8  2023    4    2
# 92         28         79         4         8   28079004_8_8  2023    4    3
# 93         28         79         4         8   28079004_8_8  2023    4    4
# 94         28         79         4         8   28079004_8_8  2023    4    5
#
#      H01 V01   H02 V02   H03 V03   H04 V04   H05 V05   H06 V06   H07 V07  \
# 90  10.0   V  14.0   V   9.0   V   7.0   V   3.0   V   2.0   V   4.0   V
# 91  12.0   V  16.0   V  21.0   V  15.0   V   7.0   V   6.0   V  10.0   V
# 92  11.0   V  11.0   V   9.0   V   6.0   V   5.0   V  13.0   V  28.0   V
# 93  16.0   V  38.0   V  33.0   V  22.0   V  18.0   V  21.0   V  17.0   V
# 94  14.0   V  18.0   V  13.0   V  12.0   V  10.0   V  18.0   V  33.0   V
#
# ...

# %%
df2304 = df2304.drop(columns=[e for e in df.columns if 'V' in e])

# %%
df2304.head()
# Out:
#     MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  DIA   H01   H02  \
# 90         79         4         8   28079004_8_8  2023    4    1  10.0  14.0
# 91         79         4         8   28079004_8_8  2023    4    2  12.0  16.0
# 92         79         4         8   28079004_8_8  2023    4    3  11.0  11.0
# 93         79         4         8   28079004_8_8  2023    4    4  16.0  38.0
# 94         79         4         8   28079004_8_8  2023    4    5  14.0  18.0
#
#      H03   H04   H05   H06   H07   H08   H09   H10    H11    H12   H13   H14  \
# 90   9.0   7.0   3.0   2.0   4.0   6.0  14.0  15.0   11.0   10.0   7.0   7.0
# 91  21.0  15.0   7.0   6.0  10.0  20.0  30.0  27.0   17.0   10.0   7.0   5.0
# 92   9.0   6.0   5.0  13.0  28.0  52.0  57.0  44.0   44.0   36.0  33.0  27.0
# 93  33.0  22.0  18.0  21.0  17.0  67.0  50.0  32.0   24.0   20.0  14.0  10.0
# 94  13.0  12.0  10.0  18.0  33.0  53.0  65.0  26.0  115.0  132.0  23.0  15.0
#
# ...

# %%
df2304.drop(['MUNICIPIO', 'MAGNITUD', 'PUNTO_MUESTREO'], axis=1, inplace = True)

# %%
df2304.head()
# Out:
#     ESTACION   ANO  MES  DIA   H01   H02   H03   H04   H05   H06   H07   H08  \
# 90         4  2023    4    1  10.0  14.0   9.0   7.0   3.0   2.0   4.0   6.0
# 91         4  2023    4    2  12.0  16.0  21.0  15.0   7.0   6.0  10.0  20.0
# 92         4  2023    4    3  11.0  11.0   9.0   6.0   5.0  13.0  28.0  52.0
# 93         4  2023    4    4  16.0  38.0  33.0  22.0  18.0  21.0  17.0  67.0
# 94         4  2023    4    5  14.0  18.0  13.0  12.0  10.0  18.0  33.0  53.0
#
#      H09   H10    H11    H12   H13   H14   H15   H16   H17   H18   H19   H20  \
# 90  14.0  15.0   11.0   10.0   7.0   7.0   5.0   4.0   3.0   7.0   8.0   6.0
# 91  30.0  27.0   17.0   10.0   7.0   5.0   6.0   5.0   5.0   5.0   8.0  11.0
# 92  57.0  44.0   44.0   36.0  33.0  27.0  26.0  21.0  21.0  11.0  10.0  13.0
# 93  50.0  32.0   24.0   20.0  14.0  10.0   7.0   7.0   8.0   8.0   9.0   9.0
# 94  65.0  26.0  115.0  132.0  23.0  15.0  15.0  14.0  11.0  14.0  17.0  22.0
#
#      H21   H22   H23   H24
# ...

# %%
df2304 = df2304.rename(columns={e: e[1:] for e in df2304.columns if 'h' in e})

# %%
# Las columnas de la hora se cambian por la hora como id del 01 al 24

for e in df2304.columns:
    
    if 'h' in e: df = df2304.rename({e: e[1:]})
    else: pass

# %%
df2304.head()
# Out:
#     ESTACION   ANO  MES  DIA   H01   H02   H03   H04   H05   H06   H07   H08  \
# 90         4  2023    4    1  10.0  14.0   9.0   7.0   3.0   2.0   4.0   6.0
# 91         4  2023    4    2  12.0  16.0  21.0  15.0   7.0   6.0  10.0  20.0
# 92         4  2023    4    3  11.0  11.0   9.0   6.0   5.0  13.0  28.0  52.0
# 93         4  2023    4    4  16.0  38.0  33.0  22.0  18.0  21.0  17.0  67.0
# 94         4  2023    4    5  14.0  18.0  13.0  12.0  10.0  18.0  33.0  53.0
#
#      H09   H10    H11    H12   H13   H14   H15   H16   H17   H18   H19   H20  \
# 90  14.0  15.0   11.0   10.0   7.0   7.0   5.0   4.0   3.0   7.0   8.0   6.0
# 91  30.0  27.0   17.0   10.0   7.0   5.0   6.0   5.0   5.0   5.0   8.0  11.0
# 92  57.0  44.0   44.0   36.0  33.0  27.0  26.0  21.0  21.0  11.0  10.0  13.0
# 93  50.0  32.0   24.0   20.0  14.0  10.0   7.0   7.0   8.0   8.0   9.0   9.0
# 94  65.0  26.0  115.0  132.0  23.0  15.0  15.0  14.0  11.0  14.0  17.0  22.0
#
#      H21   H22   H23   H24
# ...

# %%
# Suponiendo que 'df2304' es tu DataFrame y tienes las columnas 'ANO', 'MES' y 'DIA'
fechas_str = df2304['ANO'].astype(str) + '-' + df2304['MES'].astype(str) + '-' + df2304['DIA'].astype(str)
df2304['FECHA'] = pd.to_datetime(fechas_str, errors='coerce')

# Mostrar el resultado con la nueva columna 'FECHA'
df2304.head()
# Out:
#     ESTACION   ANO  MES  DIA   H01   H02   H03   H04   H05   H06   H07   H08  \
# 90         4  2023    4    1  10.0  14.0   9.0   7.0   3.0   2.0   4.0   6.0
# 91         4  2023    4    2  12.0  16.0  21.0  15.0   7.0   6.0  10.0  20.0
# 92         4  2023    4    3  11.0  11.0   9.0   6.0   5.0  13.0  28.0  52.0
# 93         4  2023    4    4  16.0  38.0  33.0  22.0  18.0  21.0  17.0  67.0
# 94         4  2023    4    5  14.0  18.0  13.0  12.0  10.0  18.0  33.0  53.0
#
#      H09   H10    H11    H12   H13   H14   H15   H16   H17   H18   H19   H20  \
# 90  14.0  15.0   11.0   10.0   7.0   7.0   5.0   4.0   3.0   7.0   8.0   6.0
# 91  30.0  27.0   17.0   10.0   7.0   5.0   6.0   5.0   5.0   5.0   8.0  11.0
# 92  57.0  44.0   44.0   36.0  33.0  27.0  26.0  21.0  21.0  11.0  10.0  13.0
# 93  50.0  32.0   24.0   20.0  14.0  10.0   7.0   7.0   8.0   8.0   9.0   9.0
# 94  65.0  26.0  115.0  132.0  23.0  15.0  15.0  14.0  11.0  14.0  17.0  22.0
#
#      H21   H22   H23   H24      FECHA
# ...

# %%
df = df2304.drop(['ANO', 'MES', 'DIA'], axis=1)
df.head()
# Out:
#     ESTACION   H01   H02   H03   H04   H05   H06   H07   H08   H09   H10  \
# 90         4  10.0  14.0   9.0   7.0   3.0   2.0   4.0   6.0  14.0  15.0
# 91         4  12.0  16.0  21.0  15.0   7.0   6.0  10.0  20.0  30.0  27.0
# 92         4  11.0  11.0   9.0   6.0   5.0  13.0  28.0  52.0  57.0  44.0
# 93         4  16.0  38.0  33.0  22.0  18.0  21.0  17.0  67.0  50.0  32.0
# 94         4  14.0  18.0  13.0  12.0  10.0  18.0  33.0  53.0  65.0  26.0
#
#       H11    H12   H13   H14   H15   H16   H17   H18   H19   H20   H21   H22  \
# 90   11.0   10.0   7.0   7.0   5.0   4.0   3.0   7.0   8.0   6.0  10.0  13.0
# 91   17.0   10.0   7.0   5.0   6.0   5.0   5.0   5.0   8.0  11.0  12.0  17.0
# 92   44.0   36.0  33.0  27.0  26.0  21.0  21.0  11.0  10.0  13.0  26.0  30.0
# 93   24.0   20.0  14.0  10.0   7.0   7.0   8.0   8.0   9.0   9.0  13.0  15.0
# 94  115.0  132.0  23.0  15.0  15.0  14.0  11.0  14.0  17.0  22.0  32.0  76.0
#
#      H23   H24      FECHA
# 90  11.0  16.0 2023-04-01
# ...

# %%
df.dtypes
# Out:
# ESTACION             int64
# H01                float64
# H02                float64
# H03                float64
# H04                float64
# H05                float64
# H06                float64
# H07                float64
# H08                float64
# H09                float64
# H10                float64
# H11                float64
# H12                float64
# H13                float64
# H14                float64
# H15                float64
# H16                float64
# H17                float64
# H18                float64
# H19                float64
# H20                float64
# H21                float64
# H22                float64
# H23                float64
# H24                float64
# FECHA       datetime64[ns]
# dtype: object

# %%
# Repetir cada fila 24 veces
df = pd.concat([df] * 24, ignore_index=True)

# %%
# Cambiar los nombres de las columnas eliminando los 0
df.columns = [e[1:] if e.startswith('0') else e for e in df.columns]

# %%
# Renombrar la columna '24' como '0'
df = df.rename(columns={'24': '0'})

# %%
df.head()
# Out:
#    ESTACION   H01   H02   H03   H04   H05   H06   H07   H08   H09   H10  \
# 0         4  10.0  14.0   9.0   7.0   3.0   2.0   4.0   6.0  14.0  15.0
# 1         4  12.0  16.0  21.0  15.0   7.0   6.0  10.0  20.0  30.0  27.0
# 2         4  11.0  11.0   9.0   6.0   5.0  13.0  28.0  52.0  57.0  44.0
# 3         4  16.0  38.0  33.0  22.0  18.0  21.0  17.0  67.0  50.0  32.0
# 4         4  14.0  18.0  13.0  12.0  10.0  18.0  33.0  53.0  65.0  26.0
#
#      H11    H12   H13   H14   H15   H16   H17   H18   H19   H20   H21   H22  \
# 0   11.0   10.0   7.0   7.0   5.0   4.0   3.0   7.0   8.0   6.0  10.0  13.0
# 1   17.0   10.0   7.0   5.0   6.0   5.0   5.0   5.0   8.0  11.0  12.0  17.0
# 2   44.0   36.0  33.0  27.0  26.0  21.0  21.0  11.0  10.0  13.0  26.0  30.0
# 3   24.0   20.0  14.0  10.0   7.0   7.0   8.0   8.0   9.0   9.0  13.0  15.0
# 4  115.0  132.0  23.0  15.0  15.0  14.0  11.0  14.0  17.0  22.0  32.0  76.0
#
#     H23   H24      FECHA  horas
# 0  11.0  16.0 2023-04-01      0
# ...

# %%
# Ahora se junta la hora con la fecha

# Se repite cada fila 24 veces


# Crear una lista con 24 copias del DataFrame
lista_de_copias = [df.copy() for _ in range(24)]

# Concatenar las copias en un solo DataFrame
df = pd.concat(lista_de_copias)

# %%
df.head()
# Out:
#     ESTACION   H01   H02   H03   H04   H05   H06   H07   H08   H09   H10  \
# 90         4  10.0  14.0   9.0   7.0   3.0   2.0   4.0   6.0  14.0  15.0
# 91         4  12.0  16.0  21.0  15.0   7.0   6.0  10.0  20.0  30.0  27.0
# 92         4  11.0  11.0   9.0   6.0   5.0  13.0  28.0  52.0  57.0  44.0
# 93         4  16.0  38.0  33.0  22.0  18.0  21.0  17.0  67.0  50.0  32.0
# 94         4  14.0  18.0  13.0  12.0  10.0  18.0  33.0  53.0  65.0  26.0
#
#       H11    H12   H13   H14   H15   H16   H17   H18   H19   H20   H21   H22  \
# 90   11.0   10.0   7.0   7.0   5.0   4.0   3.0   7.0   8.0   6.0  10.0  13.0
# 91   17.0   10.0   7.0   5.0   6.0   5.0   5.0   5.0   8.0  11.0  12.0  17.0
# 92   44.0   36.0  33.0  27.0  26.0  21.0  21.0  11.0  10.0  13.0  26.0  30.0
# 93   24.0   20.0  14.0  10.0   7.0   7.0   8.0   8.0   9.0   9.0  13.0  15.0
# 94  115.0  132.0  23.0  15.0  15.0  14.0  11.0  14.0  17.0  22.0  32.0  76.0
#
#      H23   H24      FECHA
# 90  11.0  16.0 2023-04-01
# ...

# %%
# Se quitan los 0 de los nombres de las columnas

df.columns = [e[1:] if e[0] == '0' else e for e in df.columns]

# Se cambia el nombre de la columna 24 por 00

df = df.rename({'24': '0'})

# %%
# Se hace una lista con las horas para despues convertir dicha lista en una columna

horas = []

for i in range(0, len(df), 24):

    for e in range(24):

        horas.append(e)

# %%
import pandas as pd

# Suponiendo que 'horas' es una lista o serie de valores
# y 'df' es tu DataFrame
df['horas'] = horas

# %%
valores = []

# Iterar sobre las filas del DataFrame
for index, row in df.iterrows():
    # Acceder al valor de la columna "horas" en cada fila y añadirlo a la lista
    valores.append(row['horas'])

# %%
df.head()
# Out:
#     ESTACION   H01   H02   H03   H04   H05   H06   H07   H08   H09   H10  \
# 90         4  10.0  14.0   9.0   7.0   3.0   2.0   4.0   6.0  14.0  15.0
# 91         4  12.0  16.0  21.0  15.0   7.0   6.0  10.0  20.0  30.0  27.0
# 92         4  11.0  11.0   9.0   6.0   5.0  13.0  28.0  52.0  57.0  44.0
# 93         4  16.0  38.0  33.0  22.0  18.0  21.0  17.0  67.0  50.0  32.0
# 94         4  14.0  18.0  13.0  12.0  10.0  18.0  33.0  53.0  65.0  26.0
#
#       H11    H12   H13   H14   H15   H16   H17   H18   H19   H20   H21   H22  \
# 90   11.0   10.0   7.0   7.0   5.0   4.0   3.0   7.0   8.0   6.0  10.0  13.0
# 91   17.0   10.0   7.0   5.0   6.0   5.0   5.0   5.0   8.0  11.0  12.0  17.0
# 92   44.0   36.0  33.0  27.0  26.0  21.0  21.0  11.0  10.0  13.0  26.0  30.0
# 93   24.0   20.0  14.0  10.0   7.0   7.0   8.0   8.0   9.0   9.0  13.0  15.0
# 94  115.0  132.0  23.0  15.0  15.0  14.0  11.0  14.0  17.0  22.0  32.0  76.0
#
#      H23   H24      FECHA  horas
# ...

# %%
df.head(50)
# Out:
#      ESTACION   H01   H02   H03   H04   H05   H06   H07   H08   H09   H10  \
# 90          4  10.0  14.0   9.0   7.0   3.0   2.0   4.0   6.0  14.0  15.0
# 91          4  12.0  16.0  21.0  15.0   7.0   6.0  10.0  20.0  30.0  27.0
# 92          4  11.0  11.0   9.0   6.0   5.0  13.0  28.0  52.0  57.0  44.0
# 93          4  16.0  38.0  33.0  22.0  18.0  21.0  17.0  67.0  50.0  32.0
# 94          4  14.0  18.0  13.0  12.0  10.0  18.0  33.0  53.0  65.0  26.0
# 95          4  72.0  27.0  47.0  30.0  20.0   8.0  34.0  49.0  54.0  46.0
# 96          4  40.0   8.0   7.0   5.0   5.0   8.0  28.0  39.0  47.0  34.0
# 97          4  70.0  68.0  47.0  42.0  36.0  28.0  35.0  38.0  44.0  32.0
# 98          4  91.0  77.0  46.0  32.0  37.0  36.0  41.0  45.0  43.0  31.0
# 99          4  43.0  63.0  35.0  25.0  10.0  28.0  50.0  65.0  70.0  68.0
# 100         4  13.0  20.0  26.0  19.0  23.0  25.0  40.0  70.0  78.0  78.0
# 101         4  11.0   9.0   8.0   5.0   3.0   4.0   9.0  14.0  47.0  35.0
# ...

# %%
df = df.drop([f'0', f'1', f'2', f'3', f'4', f'5', f'6', f'7', f'8', f'9', f'10', f'11', f'12', f'13', f'14', f'15'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 df = df.drop([f'0', f'1', f'2', f'3', f'4', f'5', f'6', f'7', f'8', f'9', f'10', f'11', f'12', f'13', f'14', f'15'], axis=1)
#
# File ~\anaconda3\envs\proyecto\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
# ...

# %%
df = df.with_columns(pl.Series(horas).alias('horas'))

# %%
# Se quitan los 0 de los nombres de las columnas

df2304.columns = [e[1:] if e[0] == '0' else e for e in df.columns]

# Se cambia el nombre de la columna 24 por 00

df2304 = df2304.rename({'24': '0'})

# %%
horas = []

for i in range(0, len(df2304), 24):

    for e in range(24):

        horas.append(e)

# %%
df.head()

# %%
df = df.with_columns(pl.Series(horas).alias('horas'))

# %%
# Se quiere tener una columna con la fecha en formato Year-Month-Day hour:minute:second

# Primero se crea una columna juntando año, mes y día

fechas = []

for i in range(len(df)):

    fechas.append(f"{df2304['ANO'][i]}-{df2304['MES'][i]}-{df2304['DIA'][i]}")


df = df2304.with_columns(pl.Series(fechas).alias('fecha'))

df = df.drop(['ANO', 'MES', 'DIA'])

# %%
df2304["DIA"]

# %%
pd.to_datetime(df2304[['ANO', 'MES', 'DIA']], format='%Y-%m-%d')

# %%
import pandas as pd

# Crear un DataFrame de ejemplo
data = {
    'Fecha': ['2023-01-01', '2023-01-01', '2023-01-02', '2023-01-02', '2023-01-03'],
    'Hora': ['H01', 'H02', 'H01', 'H02', 'H01'],
    'Valor': [10.0, 15.0, 12.0, 18.0, 9.0]
}

df = pd.DataFrame(data)

# Mostrar el DataFrame original
print("DataFrame Original:")
print(df)

# Aplicar una tabla pivote para reorganizar los datos
pivot_df = df.pivot_table(index='Fecha', columns='Hora', values='Valor')

# Mostrar el resultado de la tabla pivote
print("\nTabla Pivote:")
print(pivot_df)

# %%
df
